# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import os 
import osmnx as ox
import networkx as nx

# %%
# read csv into dataframe
df_all = pd.read_csv("df_all.csv")

# %%
# timestamps to datetime
df_all['iso_timestamp'] = pd.to_datetime(df_all['iso_timestamp'], utc=True, format='mixed')

# change columns to numerics
print(df_all.dtypes)
numeric_cols = [
    "channels_in", "channels_out", "channels_unknown", "channels_all", 
    "site_temperature", "site_rain_accumulation", "site_snow_accumulation"]

df_all[numeric_cols] = df_all[numeric_cols].apply(pd.to_numeric, errors='coerce')

df_all["count"] = df_all[["channels_out", "channels_in", "channels_unknown"]].fillna(0).sum(axis=1)
# Out:
# operator_name                          object
# domain_name                            object
# domain_id                               int64
# counter_site                           object
# counter_site_id                         int64
# counter_serial                         object
# longitude                             float64
# latitude                              float64
# timezone                               object
# iso_timestamp             datetime64[ns, UTC]
# channels_in                           float64
# channels_out                          float64
# channels_unknown                      float64
# channels_all                            int64
# site_temperature                      float64
# site_rain_accumulation                float64
# site_snow_accumulation                float64
# dtype: object

# %%
# subset of dataframe just for one town 
df_domain = df_all[df_all["domain_name"] == "Stadt Heidelberg"] # change domain name here for other towns
df_domain = df_domain[df_domain["counter_site"] != "Schlierbacher Landstraße"] # i do not understand why this site doesn't work
df_domain = df_domain[df_domain["counter_site"] != "Ernst-Walz-Brücke West - alt"] # no overlap with many sites
title_domain = df_domain["domain_name"].iloc[0]
print(title_domain)
df_domain_grouped = df_domain.groupby("counter_site")

# get coordinates for every counter site
domain_coords = {
    name: (
        df_domain_grouped.get_group(name)["latitude"].iloc[0],
        df_domain_grouped.get_group(name)["longitude"].iloc[0]
    )
    for name in df_domain_grouped.groups.keys()
}
domain_coords
# Out:
# Stadt Heidelberg
# {'Bahnstadtpromenade': (np.float64(49.39770881177102),
#   np.float64(8.672678949737529)),
#  'Berliner Straße Querschnitt': (np.float64(49.42197166293551),
#   np.float64(8.677004169311507)),
#  'Eppelheimer Str. Querschnitt': (np.float64(49.40470762611589),
#   np.float64(8.64976028739517)),
#  'Ernst-Walz-Brücke Querschnitt': (np.float64(49.40953402601704),
#   np.float64(8.676711154365599)),
#  'Gaisbergstraße': (np.float64(49.406723), np.float64(8.69424)),
#  'Hardtstraße': (np.float64(49.3886384101731), np.float64(8.676692652778558)),
#  'Kurfürstenanlage Querschnitt': (np.float64(49.40648754349749),
#   np.float64(8.68846627824381)),
#  'Liebermannstraße': (np.float64(49.39632740406388),
#   np.float64(8.688098472233529)),
#  'Mannheimer Straße': (np.float64(49.4118), np.float64(8.65914)),
#  'Plöck': (np.float64(49.40913), np.float64(8.698543)),
#  'Rohrbacher Straße Querschnitt': (np.float64(49.39768239906317),
#   np.float64(8.689534722556413)),
#  'Thedor-Heuss-Brücke Querschnitt': (np.float64(49.41179170458847),
#   np.float64(8.692717007248563)),
#  'Ziegelhäuser Landstraße': (np.float64(49.41925887156788),
#   np.float64(8.725964292061843))}

# %%
# we need a reference latitude for the conversion
lat0 = np.mean([coord[0] for coord in domain_coords.values()])

# function to convert lat/lon to x/y in meters
def latlon_to_xy(coord, lat0=lat0):
    lat, lon = coord
    R = 6371000 # radius of earth in meters
    x = R * np.radians(lon) * np.cos(np.radians(lat0))
    y = R * np.radians(lat)
    return np.array([x, y])

# distance matrix
sites1 = list(domain_coords.keys())
dist_matrix_euclid = pd.DataFrame(index=sites1, columns=sites1, dtype=float)

# compute euclidean distances and fill the distance matrix
for a in sites1:
    for b in sites1:
        p1 = latlon_to_xy(domain_coords[a])
        p2 = latlon_to_xy(domain_coords[b])
        dist_matrix_euclid.loc[a, b] = np.linalg.norm(p1 - p2)

dist_matrix_euclid
# Out:
#                                  Bahnstadtpromenade  \
# Bahnstadtpromenade                         0.000000
# Berliner Straße Querschnitt             2715.995405
# Eppelheimer Str. Querschnitt            1831.782126
# Ernst-Walz-Brücke Querschnitt           1346.880384
# Gaisbergstraße                          1854.272217
# Hardtstraße                             1049.559112
# Kurfürstenanlage Querschnitt            1502.547094
# Liebermannstraße                        1126.181474
# Mannheimer Straße                       1847.884009
# Plöck                                   2261.595620
# Rohrbacher Straße Querschnitt           1219.578089
# Thedor-Heuss-Brücke Querschnitt         2134.051878
# Ziegelhäuser Landstraße                 4539.385588
#
#                                  Berliner Straße Querschnitt  \
# Bahnstadtpromenade                               2715.995405
# Berliner Straße Querschnitt                         0.000000
# Eppelheimer Str. Querschnitt                     2751.497586
# Ernst-Walz-Brücke Querschnitt                    1383.164613
# Gaisbergstraße                                   2104.795074
# Hardtstraße                                      3706.557126
# Kurfürstenanlage Querschnitt                     1911.078316
# Liebermannstraße                                 2962.340991
# Mannheimer Straße                                1717.525447
# Plöck                                            2113.674606
# Rohrbacher Straße Querschnitt                    2848.952408
# Thedor-Heuss-Brücke Querschnitt                  1604.315149
# Ziegelhäuser Landstraße                          3555.257309
#
#                                  Eppelheimer Str. Querschnitt  \
# Bahnstadtpromenade                                1831.782126
# Berliner Straße Querschnitt                       2751.497586
# Eppelheimer Str. Querschnitt                         0.000000
# Ernst-Walz-Brücke Querschnitt                     2022.492935
# Gaisbergstraße                                    3226.056914
# Hardtstraße                                       2643.851670
# Kurfürstenanlage Querschnitt                      2807.499718
# Liebermannstraße                                  2926.236297
# Mannheimer Straße                                 1040.442063
# Plöck                                             3563.691606
# Rohrbacher Straße Querschnitt                     2981.958572
# Thedor-Heuss-Brücke Querschnitt                   3206.336231
# Ziegelhäuser Landstraße                           5746.137844
#
#                                  Ernst-Walz-Brücke Querschnitt  \
# Bahnstadtpromenade                                 1346.880384
# Berliner Straße Querschnitt                        1383.164613
# Eppelheimer Str. Querschnitt                       2022.492935
# Ernst-Walz-Brücke Querschnitt                         0.000000
# Gaisbergstraße                                     1306.223348
# Hardtstraße                                        2323.486857
# Kurfürstenanlage Querschnitt                        915.503147
# Liebermannstraße                                   1683.850249
# Mannheimer Straße                                  1296.062794
# Plöck                                              1580.249688
# Rohrbacher Straße Querschnitt                      1611.698945
# Thedor-Heuss-Brücke Querschnitt                    1184.977311
# Ziegelhäuser Landstraße                            3724.089353
#
# Ernst-Walz-Brücke Querschnitt                        1184.977311
# Gaisbergstraße                                        574.285382
# Hardtstraße                                          2823.552761
# Kurfürstenanlage Querschnitt                          665.168628
# Liebermannstraße                                     1751.720878
# Mannheimer Straße                                    2429.414954
# Plöck                                                 515.058788
# Rohrbacher Straße Querschnitt                        1585.688907
# Thedor-Heuss-Brücke Querschnitt                         0.000000
# Ziegelhäuser Landstraße                              2544.823519
#
#                                  Ziegelhäuser Landstraße
# Bahnstadtpromenade                           4539.385588
# Berliner Straße Querschnitt                  3555.257309
# Eppelheimer Str. Querschnitt                 5746.137844
# Ernst-Walz-Brücke Querschnitt                3724.089353
# Gaisbergstraße                               2685.465527
# Hardtstraße                                  4929.705270
# Kurfürstenanlage Querschnitt                 3062.301095
# Liebermannstraße                             3742.712418
# Mannheimer Straße                            4905.593672
# Plöck                                        2281.418024
# Rohrbacher Straße Querschnitt                3564.213161
# Thedor-Heuss-Brücke Querschnitt              2544.823519
# Ziegelhäuser Landstraße                         0.000000

# %%
# compute median of lats and lons for center point
lats = [coord[0] for coord in domain_coords.values()]
cp_lat = np.median(lats)

lons = [coord[1] for coord in domain_coords.values()]
cp_lon = np.median(lons)

# set median as center point 
center_point = (cp_lat, cp_lon)  

# access streetmaps graph with bike lanes, with median cp and x km radius (adjust if needed)
G = ox.graph_from_point(center_point, dist=6000, network_type='bike')

# %%
# nodes in our graph are our counter sites 
snapped_nodes = {}
for name, (lat, lon) in domain_coords.items():
    node = ox.distance.nearest_nodes(G, X=lon, Y=lat)
    snapped_nodes[name] = node

# %%
# now name the nodes and compute shortest distance by bike
distances1 = {}
for i in snapped_nodes:
    for j in snapped_nodes:
        if (j, i) in distances1:
            distances1[(i, j)] = distances1[(j, i)]
            continue
        if i == j:
            distances1[(i, j)] = 0
            continue
        d = nx.shortest_path_length(G, snapped_nodes[i], snapped_nodes[j], weight='length')
        distances1[(i, j)] = d
        print(f"distance between {i} and {j}: {d:.1f} m")
# Out:
# distance between Bahnstadtpromenade and Berliner Straße Querschnitt: 3505.2 m
# distance between Bahnstadtpromenade and Eppelheimer Str. Querschnitt: 2126.5 m
# distance between Bahnstadtpromenade and Ernst-Walz-Brücke Querschnitt: 1809.7 m
# distance between Bahnstadtpromenade and Gaisbergstraße: 2136.7 m
# distance between Bahnstadtpromenade and Hardtstraße: 1463.8 m
# distance between Bahnstadtpromenade and Kurfürstenanlage Querschnitt: 1726.8 m
# distance between Bahnstadtpromenade and Liebermannstraße: 1312.8 m
# distance between Bahnstadtpromenade and Mannheimer Straße: 2481.6 m
# distance between Bahnstadtpromenade and Plöck: 2601.4 m
# distance between Bahnstadtpromenade and Rohrbacher Straße Querschnitt: 1569.8 m
# distance between Bahnstadtpromenade and Thedor-Heuss-Brücke Querschnitt: 2516.8 m
# distance between Bahnstadtpromenade and Ziegelhäuser Landstraße: 5201.0 m
# distance between Berliner Straße Querschnitt and Eppelheimer Str. Querschnitt: 4030.9 m
# distance between Berliner Straße Querschnitt and Ernst-Walz-Brücke Querschnitt: 1854.4 m
# distance between Berliner Straße Querschnitt and Gaisbergstraße: 3102.2 m
# distance between Berliner Straße Querschnitt and Hardtstraße: 4568.3 m
# distance between Berliner Straße Querschnitt and Kurfürstenanlage Querschnitt: 2988.8 m
# distance between Berliner Straße Querschnitt and Liebermannstraße: 3738.3 m
# distance between Berliner Straße Querschnitt and Mannheimer Straße: 3064.4 m
# distance between Berliner Straße Querschnitt and Plöck: 3160.2 m
# distance between Berliner Straße Querschnitt and Rohrbacher Straße Querschnitt: 3576.3 m
# distance between Berliner Straße Querschnitt and Thedor-Heuss-Brücke Querschnitt: 2458.5 m
# distance between Berliner Straße Querschnitt and Ziegelhäuser Landstraße: 4739.5 m
# distance between Eppelheimer Str. Querschnitt and Ernst-Walz-Brücke Querschnitt: 2415.7 m
# distance between Eppelheimer Str. Querschnitt and Gaisbergstraße: 3581.8 m
# distance between Eppelheimer Str. Querschnitt and Hardtstraße: 3452.7 m
# distance between Eppelheimer Str. Querschnitt and Kurfürstenanlage Querschnitt: 3171.9 m
# distance between Eppelheimer Str. Querschnitt and Liebermannstraße: 3420.6 m
# distance between Eppelheimer Str. Querschnitt and Mannheimer Straße: 2070.2 m
# distance between Eppelheimer Str. Querschnitt and Plöck: 3885.1 m
# distance between Eppelheimer Str. Querschnitt and Rohrbacher Straße Querschnitt: 3463.0 m
# distance between Eppelheimer Str. Querschnitt and Thedor-Heuss-Brücke Querschnitt: 3709.9 m
# distance between Eppelheimer Str. Querschnitt and Ziegelhäuser Landstraße: 6332.2 m
# distance between Ernst-Walz-Brücke Querschnitt and Gaisbergstraße: 2372.7 m
# distance between Ernst-Walz-Brücke Querschnitt and Hardtstraße: 3589.2 m
# distance between Ernst-Walz-Brücke Querschnitt and Kurfürstenanlage Querschnitt: 2004.6 m
# distance between Ernst-Walz-Brücke Querschnitt and Liebermannstraße: 2759.2 m
# distance between Ernst-Walz-Brücke Querschnitt and Mannheimer Straße: 2098.7 m
# distance between Ernst-Walz-Brücke Querschnitt and Plöck: 2505.0 m
# distance between Ernst-Walz-Brücke Querschnitt and Rohrbacher Straße Querschnitt: 2597.1 m
# distance between Ernst-Walz-Brücke Querschnitt and Thedor-Heuss-Brücke Querschnitt: 1803.2 m
# distance between Ernst-Walz-Brücke Querschnitt and Ziegelhäuser Landstraße: 4016.5 m
# distance between Gaisbergstraße and Hardtstraße: 2822.7 m
# distance between Gaisbergstraße and Kurfürstenanlage Querschnitt: 557.8 m
# distance between Gaisbergstraße and Liebermannstraße: 1372.7 m
# distance between Gaisbergstraße and Mannheimer Straße: 2946.2 m
# distance between Gaisbergstraße and Plöck: 578.1 m
# distance between Gaisbergstraße and Rohrbacher Straße Querschnitt: 1200.1 m
# distance between Gaisbergstraße and Thedor-Heuss-Brücke Querschnitt: 554.0 m
# distance between Gaisbergstraße and Ziegelhäuser Landstraße: 3177.6 m
# distance between Hardtstraße and Kurfürstenanlage Querschnitt: 2518.6 m
# distance between Hardtstraße and Liebermannstraße: 1450.0 m
# distance between Hardtstraße and Mannheimer Straße: 3677.8 m
# distance between Hardtstraße and Plöck: 3343.3 m
# distance between Hardtstraße and Rohrbacher Straße Querschnitt: 1707.0 m
# distance between Hardtstraße and Thedor-Heuss-Brücke Querschnitt: 3308.6 m
# distance between Hardtstraße and Ziegelhäuser Landstraße: 5942.9 m
# distance between Kurfürstenanlage Querschnitt and Liebermannstraße: 1527.7 m
# distance between Kurfürstenanlage Querschnitt and Mannheimer Straße: 2566.3 m
# distance between Kurfürstenanlage Querschnitt and Plöck: 874.6 m
# distance between Kurfürstenanlage Querschnitt and Rohrbacher Straße Querschnitt: 1355.1 m
# distance between Kurfürstenanlage Querschnitt and Thedor-Heuss-Brücke Querschnitt: 790.0 m
# distance between Kurfürstenanlage Querschnitt and Ziegelhäuser Landstraße: 3474.2 m
# distance between Liebermannstraße and Mannheimer Straße: 3061.5 m
# distance between Liebermannstraße and Plöck: 1893.3 m
# distance between Liebermannstraße and Rohrbacher Straße Querschnitt: 257.0 m
# distance between Liebermannstraße and Thedor-Heuss-Brücke Querschnitt: 1869.0 m
# distance between Liebermannstraße and Ziegelhäuser Landstraße: 4492.9 m
# distance between Mannheimer Straße and Plöck: 3064.5 m
# distance between Mannheimer Straße and Rohrbacher Straße Querschnitt: 3079.4 m
# distance between Mannheimer Straße and Thedor-Heuss-Brücke Querschnitt: 2880.8 m
# distance between Mannheimer Straße and Ziegelhäuser Landstraße: 5295.7 m
# distance between Plöck and Rohrbacher Straße Querschnitt: 1672.7 m
# distance between Plöck and Thedor-Heuss-Brücke Querschnitt: 880.1 m
# distance between Plöck and Ziegelhäuser Landstraße: 2701.0 m
# distance between Rohrbacher Straße Querschnitt and Thedor-Heuss-Brücke Querschnitt: 1848.6 m
# distance between Rohrbacher Straße Querschnitt and Ziegelhäuser Landstraße: 4472.6 m
# distance between Thedor-Heuss-Brücke Querschnitt and Ziegelhäuser Landstraße: 2758.5 m

# %%
# compute all the routes as well and store them in a dict
# you can plot it too! (uncomment last line, do not recommend it for stuttgart though)
routes = {}

keys = list(snapped_nodes.keys())

for i in keys:
    for j in keys:
        if (j, i) in routes:
            routes[(i, j)] = routes[(j, i)]
            continue
        if i == j:
            routes[(i, j)] = [snapped_nodes[i]]
            continue
        r = nx.shortest_path(G, snapped_nodes[i], snapped_nodes[j], weight='length')
        routes[(i, j)] = r
        #ox.plot_graph_route(G, r)

# %% [markdown]
# - Heidelberg: 15 counter
# - Stuttgart: 15 counter
# - Ludwigsburg: 15 counter
# - Mannheim: 14 counter
# - Freiburg: 10 counter
# - Reutlingen: 7 counter
# - Konstanz: 6 counter
# - Tübingen: 5 counter
# - Heilbronn: 4 counter
# - Lörrach: 2 counter

# %%
# pivot table for correlation matrix
df_domain_pivot = df_domain.pivot_table(
    index = 'iso_timestamp',
    columns = 'counter_site',
    values = 'count',
    aggfunc='sum'
)

# we want to see how many timestamps have data for both sites
mask = df_domain_pivot.notna().astype(int)
overlap = mask.T.dot(mask)
overlap
# Out:
# Ernst-Walz-Brücke Querschnitt                           54159
# Gaisbergstraße                                          45463
# Hardtstraße                                             39757
# Kurfürstenanlage Querschnitt                            54159
# Liebermannstraße                                        52600
# Mannheimer Straße                                       54158
# Plöck                                                   46616
# Rohrbacher Straße Querschnitt                           54159
# Thedor-Heuss-Brücke Querschnitt                         54158
# Ziegelhäuser Landstraße                                 34311
#
# counter_site                     Liebermannstraße  Mannheimer Straße  Plöck  \
# counter_site
# Bahnstadtpromenade                          30216              30349  22807
# Berliner Straße Querschnitt                 44791              46350  39294
# Eppelheimer Str. Querschnitt                46513              48072  40530
# Ernst-Walz-Brücke Querschnitt               60182              87503  79961
# Gaisbergstraße                              51591              78778  71236
# Hardtstraße                                 38198              39757  32716
# Kurfürstenanlage Querschnitt                52600              54158  46616
# Liebermannstraße                            60182              60181  52639
# Mannheimer Straße                           60181              87503  79960
# Plöck                                       52639              79960  79961
# Rohrbacher Straße Querschnitt               60182              61740  54198
# Thedor-Heuss-Brücke Querschnitt             60181              64055  56513
# Ziegelhäuser Landstraße                     34193              34324  26782
#
# counter_site                     Rohrbacher Straße Querschnitt  \
# counter_site
# Bahnstadtpromenade                                       30349
# Berliner Straße Querschnitt                              46350
# Eppelheimer Str. Querschnitt                             48072
# Ernst-Walz-Brücke Querschnitt                            61741
# Gaisbergstraße                                           53017
# Hardtstraße                                              39757
# Kurfürstenanlage Querschnitt                             54159
# Liebermannstraße                                         60182
# Mannheimer Straße                                        61740
# Plöck                                                    54198
# Rohrbacher Straße Querschnitt                            61741
# Thedor-Heuss-Brücke Querschnitt                          61740
# Ziegelhäuser Landstraße                                  34324
#
# counter_site                     Thedor-Heuss-Brücke Querschnitt  \
# counter_site
# Bahnstadtpromenade                                         30350
# Berliner Straße Querschnitt                                46351
# Eppelheimer Str. Querschnitt                               48072
# Ernst-Walz-Brücke Querschnitt                              64056
# Gaisbergstraße                                             55332
# Hardtstraße                                                39776
# Kurfürstenanlage Querschnitt                               54158
# Liebermannstraße                                           60181
# Mannheimer Straße                                          64055
# Plöck                                                      56513
# Rohrbacher Straße Querschnitt                              61740
# Thedor-Heuss-Brücke Querschnitt                            64075
# Ziegelhäuser Landstraße                                    34324
#
# counter_site                     Ziegelhäuser Landstraße
# counter_site
# Bahnstadtpromenade                                 22469
# Berliner Straße Querschnitt                        25070
# Eppelheimer Str. Querschnitt                       25567
# Ernst-Walz-Brücke Querschnitt                      34325
# Gaisbergstraße                                     27966
# Hardtstraße                                        25049
# Kurfürstenanlage Querschnitt                       34311
# Liebermannstraße                                   34193
# Mannheimer Straße                                  34324
# Plöck                                              26782
# Rohrbacher Straße Querschnitt                      34324
# Thedor-Heuss-Brücke Querschnitt                    34324
# Ziegelhäuser Landstraße                            34325

# %%
# compute correlation matrix and plot heatmap
# this shows correlation of counter sites based on their counts
corr_matrix = df_domain_pivot.corr()
plt.figure(figsize=(10,8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title(f"{title_domain}: Correlation of Counter Sites")
plt.show()

# %%
# correlation matrix for just times where all sites have data
# maybe more meaningful, still not sure
aligned = df_domain_pivot.dropna()
corr_matrix1 = aligned.corr()
plt.figure(figsize=(10,8))
sns.heatmap(corr_matrix1, annot=True, cmap='coolwarm')
plt.title(f"{title_domain}: Aligned Correlation of Counter Sites")
plt.show()

# %%
# now we want matrices for distances
# create distance matrix (for bike dist)
dist_matrix = pd.DataFrame(index=sites1, columns=sites1)
for (site1, site2), dist in distances1.items():
    dist_matrix.loc[site1, site2] = dist
    dist_matrix.loc[site2, site1] = dist

# fill diagonal with 0
dist_matrix.fillna(0, inplace=True)

# check shape
dist_matrix.shape

# heatmap for distances 
plt.figure(figsize=(15,13))
sns.heatmap(dist_matrix.astype(int), annot=True, cmap='YlGnBu')
plt.title(f"{title_domain}: Bike distance between counter sites (m)")
plt.show()

# %%
# now again for euclidian distances (we computed matrix already above)
plt.figure(figsize=(15,13))
sns.heatmap(dist_matrix_euclid.astype(float), annot=True, cmap='YlGnBu')
plt.title(f"{title_domain}: Euclidian distance between counter sites (m)")
plt.show()

# %%
# euclidian vs bike distance scatter plot
euclidian_distances = []
bike_distances = []
for site_a in sites1:
    for site_b in sites1:
        if site_a >= site_b:
            continue
        euclidian_distances.append(dist_matrix_euclid.loc[site_a, site_b])
        bike_distances.append(dist_matrix.loc[site_a, site_b])
plt.scatter(euclidian_distances, bike_distances)
plt.xlabel("Euclidian Distance (meters)")
plt.ylabel("Bike Distance (meters)")
plt.title(f"{title_domain}: Euclidian vs Bike Distance between Counter Sites")
plt.show()

# %%
# euclidian distance vs correlation plot
# using euclidian distance and unaligned correlation
correlations = []
distance_values = []
for i in range(len(sites1)):
    for j in range(i + 1, len(sites1)):
        site1 = sites1[i]
        site2 = sites1[j]
        distance = dist_matrix_euclid.loc[site1, site2]
        correlation = corr_matrix.loc[site1, site2]
        distance_values.append(distance)
        correlations.append(correlation)

plt.scatter(distance_values, correlations)
plt.xlabel("Euclidian Distance (meters)")
plt.ylabel("Correlation")
plt.title(f"{title_domain}: Euclidian Distance vs Correlation between Counter Sites")
plt.show()

# %%
# distance vs correlation plot
# using bike distance and unaligned correlation
correlations = []
distance_values = []
for i in range(len(sites1)):
    for j in range(i + 1, len(sites1)):
        site1 = sites1[i]
        site2 = sites1[j]
        distance = dist_matrix.loc[site1, site2]
        correlation = corr_matrix.loc[site1, site2]
        distance_values.append(distance)
        correlations.append(correlation)


plt.scatter(distance_values, correlations)
plt.xlabel("Distance (m)")
plt.ylabel("Correlation")
plt.title(f"{title_domain}: Distance vs Correlation between Counter Sites")
plt.show()

# %%
# distance vs correlation plot
# using bike distance and aligned correlation
correlations = []
distance_values = []
for i in range(len(sites1)):
    for j in range(i + 1, len(sites1)):
        site1 = sites1[i]
        site2 = sites1[j]
        distance = dist_matrix.loc[site1, site2]
        correlation = corr_matrix1.loc[site1, site2]
        distance_values.append(distance)
        correlations.append(correlation)


plt.scatter(distance_values, correlations)
plt.xlabel("Distance (m)")
plt.ylabel("Correlation")
plt.title(f"{title_domain}: Distance vs Aligned Correlation between Counter Sites")
plt.show()
