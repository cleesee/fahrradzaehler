# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import os

import importlib
import regression_utils
importlib.reload(regression_utils)

from regression_utils import train_model

# %%
# Load all data
df_all = pd.read_csv("df_all.csv")
df_all['iso_timestamp'] = pd.to_datetime(df_all['iso_timestamp'], utc=True, format='mixed')

# Change columns to numerics
numeric_cols = [
    "channels_in", "channels_out", "channels_unknown", "channels_all",
    "site_temperature", "site_rain_accumulation", "site_snow_accumulation"]
df_all[numeric_cols] = df_all[numeric_cols].apply(pd.to_numeric, errors='coerce')

df_all["count"] = df_all[["channels_out", "channels_in", "channels_unknown"]].fillna(0).sum(axis=1)

print(f"Loaded {len(df_all):,} total records")
print(f"Cities: {df_all['domain_name'].nunique()}")
print(f"\nAvailable cities:")
for city in sorted(df_all['domain_name'].unique()):
    n_stations = df_all[df_all['domain_name'] == city]['counter_site'].nunique()
    print(f"  {city:40} ({n_stations:2} stations)")
# Out:
# Loaded 6,122,719 total records
# Cities: 22
#
# Available cities:
# Cities: 22
#
# Available cities:
#   Landeshauptstadt Stuttgart               (15 stations)
#   Landkreis Böblingen                      ( 2 stations)
#   Landeshauptstadt Stuttgart               (15 stations)
#   Landkreis Böblingen                      ( 2 stations)
#   Landratsamt Ostalbkreis                  (11 stations)
#   Landratsamt Rems-Murr-Kreis              (13 stations)
#   Landratsamt Ostalbkreis                  (11 stations)
#   Landratsamt Rems-Murr-Kreis              (13 stations)
#   Ravensburg Tws Gmbh & Co. Kg             ( 7 stations)
#   Regierungspräsidium Stuttgart Aussenstelle Heilbronn ( 1 stations)
#   Ravensburg Tws Gmbh & Co. Kg             ( 7 stations)
#   Regierungspräsidium Stuttgart Aussenstelle Heilbronn ( 1 stations)
#   Stadt Bad Säckingen                      ( 2 stations)
#   Stadt Freiburg                           (10 stations)
#   Stadt Bad Säckingen                      ( 2 stations)
#   Stadt Freiburg                           (10 stations)
#   Stadt Heidelberg                         (15 stations)
#   Stadt Heilbronn                          ( 4 stations)
#   Stadt Heidelberg                         (15 stations)
#   Stadt Heilbronn                          ( 4 stations)
#   Stadt Karlsruhe                          ( 1 stations)
#   Stadt Kirchheim Unter Teck               ( 1 stations)
#   Stadt Karlsruhe                          ( 1 stations)
#   Stadt Kirchheim Unter Teck               ( 1 stations)
#   Stadt Konstanz                           ( 6 stations)
#   Stadt Konstanz                           ( 6 stations)
#   Stadt Ludwigsburg                        (15 stations)
#   Stadt Lörrach                            ( 2 stations)
#   Stadt Ludwigsburg                        (15 stations)
#   Stadt Lörrach                            ( 2 stations)
#   Stadt Mannheim                           (14 stations)
#   Stadt Offenburg                          ( 1 stations)
#   Stadt Mannheim                           (14 stations)
#   Stadt Offenburg                          ( 1 stations)
#   Stadt Reutlingen                         ( 8 stations)
#   Stadt Singen                             ( 1 stations)
#   Stadt Reutlingen                         ( 8 stations)
#   Stadt Singen                             ( 1 stations)
#   Stadt Tübingen                           ( 5 stations)
#   Stadt Ulm                                ( 1 stations)
#   Stadt Tübingen                           ( 5 stations)
#   Stadt Ulm                                ( 1 stations)
#   Stadtverwaltung Aalen                    ( 1 stations)
#   Stadtverwaltung Aalen                    ( 1 stations)

# %%
# Load feature data
df_features = pd.read_csv('df_features.csv')
df_features['iso_timestamp'] = pd.to_datetime(df_features['iso_timestamp'], utc=True)

print(f"Loaded {len(df_features):,} feature records")
# Out:
# Loaded 6,122,719 feature records

# %%
# Define cities to process (you can modify this list)
cities_to_process = [
    "Stadt Freiburg",
    "Stadt Heidelberg",
    "Landeshauptstadt Stuttgart",
    "Stadt Mannheim",
    "Stadt Reutlingen",
    "Stadt Konstanz",
    "Stadt Tübingen",
    "Stadt Ludwigsburg",
    "Ravensburg Tws Gmbh & Co. Kg"
]

# Outlier threshold
OUTLIER_THRESHOLD = 1000

print(f"Will process {len(cities_to_process)} cities")
print(f"Outlier threshold: >{OUTLIER_THRESHOLD} hourly counts")
# Out:
# Will process 9 cities
# Outlier threshold: >1000 hourly counts

# %%
# Function to train model with optional outlier removal
def train_with_outlier_option(df_station, station_name, df_city, remove_outliers=False, threshold=500):
    """
    Train model with option to remove outliers
    
    Returns: results dict with additional 'n_train_samples' field, or None if failed
    """
    if remove_outliers:
        # Filter out outliers from station data
        df_station = df_station[df_station['channels_all'] <= threshold].copy()
        # Also filter city data to maintain consistency
        df_city = df_city[df_city['channels_all'] <= threshold].copy()
    
    if len(df_station) < 1000:
        return None
    
    results, model, features = train_model(df_station, station_name, df_city)
    
    if results is None:
        return None
    
    # Add training sample count
    # train_model uses 80/20 split
    # We need to replicate the same filtering logic to get accurate count
    from regression_utils import add_station_features
    
    # Get all stations data for pivot
    df_pivot_all = df_city.pivot_table(
        index='iso_timestamp',
        columns='counter_site',
        values='channels_all'
    )
    valid_timestamps = df_pivot_all.dropna().index
    df_station_filtered = df_station[df_station['iso_timestamp'].isin(valid_timestamps)].copy()
    
    # Check if we have any data after filtering
    if len(df_station_filtered) == 0:
        return None
    
    df_model = add_station_features(df_station_filtered, station_name, df_city)
    
    # Check if we have enough data for training
    if len(df_model) == 0:
        return None
    
    split_idx = int(len(df_model) * 0.8)
    
    # Skip if no training samples
    if split_idx == 0:
        return None
    
    results['n_train_samples'] = split_idx
    
    return results

# %%
################################################
# PROCESS ALL CITIES                           #
################################################

all_city_results = {}

for city_name in cities_to_process:
    print(f"\n{'='*80}")
    print(f"PROCESSING: {city_name}")
    print(f"{'='*80}")
    
    # Get city data
    df_city = df_features[df_features['domain_name'] == city_name].copy()
    
    if len(df_city) == 0:
        print(f"⊗ No data found for {city_name}")
        continue
    
    stations = df_city['counter_site'].unique()
    print(f"\nStations: {len(stations)}")
    print(f"Records: {len(df_city):,}")
    
    city_results = []
    
    for station_idx, station in enumerate(stations, 1):
        print(f"\n[{station_idx}/{len(stations)}] {station[:50]}")
        
        # Get station data
        df_station = df_city[df_city['counter_site'] == station].copy()
        df_station = df_station.dropna(subset=['channels_all'])
        df_station = df_station.sort_values('iso_timestamp')
        
        if len(df_station) < 1000:
            print(f"    ⊗ Skipped - only {len(df_station)} records")
            continue
        
        # Train WITHOUT outlier removal
        print("    Training WITH outliers...")
        results_with = train_with_outlier_option(df_station, station, df_city, remove_outliers=False)
        
        if results_with is None:
            print("    ⊗ Failed to train model with outliers")
            continue
        
        # Train WITH outlier removal
        print("    Training WITHOUT outliers (threshold >500)...")
        results_without = train_with_outlier_option(df_station, station, df_city, 
                                                      remove_outliers=True, threshold=OUTLIER_THRESHOLD)
        
        if results_without is None:
            print("    ⊗ Failed to train model without outliers")
            continue
        
        # Combine results
        combined = {
            'city': city_name,
            'station': station,
            'n_features': results_with['n_features'],
            'n_train_samples': results_with['n_train_samples'],
            'n_train_samples_no_outliers': results_without['n_train_samples'],
            # With outliers
            'test_r2_with': results_with['test_r2'],
            'test_rmse_with': results_with['test_rmse'],
            'test_mae_with': results_with['test_mae'],
            # Without outliers
            'test_r2_without': results_without['test_r2'],
            'test_rmse_without': results_without['test_rmse'],
            'test_mae_without': results_without['test_mae'],
            # Difference
            'delta_r2': results_without['test_r2'] - results_with['test_r2']
        }
        
        city_results.append(combined)
        
        print(f"    WITH outliers:    R²={results_with['test_r2']:.4f} | RMSE={results_with['test_rmse']:.2f} | n={results_with['n_train_samples']}")
        print(f"    WITHOUT outliers: R²={results_without['test_r2']:.4f} | RMSE={results_without['test_rmse']:.2f} | n={results_without['n_train_samples']}")
        print(f"    ΔR² = {combined['delta_r2']:+.4f}")
    
    all_city_results[city_name] = city_results
    
    # Print city summary
    if len(city_results) > 0:
        df_city_results = pd.DataFrame(city_results)
        print(f"\n{'-'*80}")
        print(f"SUMMARY - {city_name}")
        print(f"{'-'*80}")
        print(f"Successfully trained models for {len(city_results)} stations")
        print(f"\nAverage R² WITH outliers:    {df_city_results['test_r2_with'].mean():.4f} ± {df_city_results['test_r2_with'].std():.4f}")
        print(f"Average R² WITHOUT outliers: {df_city_results['test_r2_without'].mean():.4f} ± {df_city_results['test_r2_without'].std():.4f}")
        print(f"Average ΔR²:                 {df_city_results['delta_r2'].mean():+.4f} ± {df_city_results['delta_r2'].std():.4f}")

print(f"\n\n{'='*80}")
print("ALL CITIES PROCESSED")
print(f"{'='*80}")
# Out:
# ================================================================================
# PROCESSING: Stadt Freiburg
# ================================================================================
#
# Stations: 10
# Records: 481,718
#
# [1/10] Wiwilibrücke
#     Training WITH outliers...
#
# Stations: 10
# Records: 481,718
#
# [1/10] Wiwilibrücke
#     Training WITH outliers...
#     Complete coverage: 6,067/112,321 hours (5.4%)
#     Complete coverage: 6,067/112,321 hours (5.4%)
#     Time frame: 2024-05-22 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (526 days, 6,067 hours)
#     Time frame: 2024-05-22 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (526 days, 6,067 hours)
#     Training WITHOUT outliers (threshold >500)...
#     Training WITHOUT outliers (threshold >500)...
#     Complete coverage: 5,721/112,270 hours (5.1%)
#     Complete coverage: 5,721/112,270 hours (5.1%)
#     Time frame: 2024-05-22 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (526 days, 5,721 hours)
#     Time frame: 2024-05-22 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (526 days, 5,721 hours)
#     WITH outliers:    R²=0.9733 | RMSE=53.05 | n=4853
#     WITHOUT outliers: R²=0.9712 | RMSE=50.37 | n=4576
#     ΔR² = -0.0021
#
# [2/10] FR2 Güterbahn / Ferd.-Weiß-Str.
#     Training WITH outliers...
#     WITH outliers:    R²=0.9733 | RMSE=53.05 | n=4853
#     WITHOUT outliers: R²=0.9712 | RMSE=50.37 | n=4576
#     ΔR² = -0.0021
#
# [2/10] FR2 Güterbahn / Ferd.-Weiß-Str.
#     Training WITH outliers...
#     Complete coverage: 6,067/112,321 hours (5.4%)
#     Complete coverage: 6,067/112,321 hours (5.4%)
#     Time frame: 2024-05-22 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (526 days, 6,067 hours)
#     Time frame: 2024-05-22 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (526 days, 6,067 hours)
#     Training WITHOUT outliers (threshold >500)...
#     Training WITHOUT outliers (threshold >500)...
#     Complete coverage: 5,721/112,270 hours (5.1%)
#     Complete coverage: 5,721/112,270 hours (5.1%)
#     Time frame: 2024-05-22 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (526 days, 5,721 hours)
#     Time frame: 2024-05-22 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (526 days, 5,721 hours)
#     WITH outliers:    R²=0.9682 | RMSE=25.60 | n=4853
#     WITHOUT outliers: R²=0.9598 | RMSE=25.36 | n=4576
#     ΔR² = -0.0083
#
# [3/10] FR1 Dreisam / Otto-Wels-Str.
#     Training WITH outliers...
#     WITH outliers:    R²=0.9682 | RMSE=25.60 | n=4853
#     WITHOUT outliers: R²=0.9598 | RMSE=25.36 | n=4576
#     ΔR² = -0.0083
#
# [3/10] FR1 Dreisam / Otto-Wels-Str.
#     Training WITH outliers...
#     Complete coverage: 6,067/112,321 hours (5.4%)
#     Complete coverage: 6,067/112,321 hours (5.4%)
#     Time frame: 2024-05-22 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (526 days, 6,067 hours)
#     Time frame: 2024-05-22 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (526 days, 6,067 hours)
#     Training WITHOUT outliers (threshold >500)...
#     Training WITHOUT outliers (threshold >500)...
#     Complete coverage: 5,721/112,270 hours (5.1%)
#     Complete coverage: 5,721/112,270 hours (5.1%)
#     Time frame: 2024-05-22 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (526 days, 5,721 hours)
#     Time frame: 2024-05-22 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (526 days, 5,721 hours)
#     WITH outliers:    R²=0.7984 | RMSE=109.33 | n=4853
#     WITHOUT outliers: R²=0.7507 | RMSE=108.87 | n=4576
#     ΔR² = -0.0478
#
# [4/10] FR3 Eschholzstr. / Egonstr. einzeln
#     Training WITH outliers...
#     WITH outliers:    R²=0.7984 | RMSE=109.33 | n=4853
#     WITHOUT outliers: R²=0.7507 | RMSE=108.87 | n=4576
#     ΔR² = -0.0478
#
# [4/10] FR3 Eschholzstr. / Egonstr. einzeln
#     Training WITH outliers...
#     Complete coverage: 6,067/112,321 hours (5.4%)
#     Complete coverage: 6,067/112,321 hours (5.4%)
#     Time frame: 2024-05-22 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (526 days, 6,067 hours)
#     Time frame: 2024-05-22 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (526 days, 6,067 hours)
#     Training WITHOUT outliers (threshold >500)...
#     Training WITHOUT outliers (threshold >500)...
#     Complete coverage: 5,721/112,270 hours (5.1%)
#     Complete coverage: 5,721/112,270 hours (5.1%)
#     Time frame: 2024-05-22 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (526 days, 5,721 hours)
#     Time frame: 2024-05-22 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (526 days, 5,721 hours)
#     WITH outliers:    R²=0.9531 | RMSE=21.28 | n=4853
#     WITHOUT outliers: R²=0.9443 | RMSE=21.01 | n=4576
#     ΔR² = -0.0087
#
# [5/10] Mundenhof 2 - Mundenhofer Str. - Waltershofen
#     Training WITH outliers...
#     WITH outliers:    R²=0.9531 | RMSE=21.28 | n=4853
#     WITHOUT outliers: R²=0.9443 | RMSE=21.01 | n=4576
#     ΔR² = -0.0087
#
# [5/10] Mundenhof 2 - Mundenhofer Str. - Waltershofen
#     Training WITH outliers...
#     Complete coverage: 6,067/112,321 hours (5.4%)
#     Complete coverage: 6,067/112,321 hours (5.4%)
#     Time frame: 2024-05-22 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (526 days, 6,067 hours)
#     Time frame: 2024-05-22 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (526 days, 6,067 hours)
#     Training WITHOUT outliers (threshold >500)...
#     Training WITHOUT outliers (threshold >500)...
#     Complete coverage: 5,721/112,270 hours (5.1%)
#     Complete coverage: 5,721/112,270 hours (5.1%)
#     Time frame: 2024-05-22 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (526 days, 5,721 hours)
#     Time frame: 2024-05-22 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (526 days, 5,721 hours)
#     WITH outliers:    R²=0.6693 | RMSE=16.40 | n=4853
#     WITHOUT outliers: R²=0.6109 | RMSE=16.27 | n=4576
#     ΔR² = -0.0583
#
# [6/10] H.-v.-Stephan-Str. 9 / JobRad - Ri. Süd
#     Training WITH outliers...
#     WITH outliers:    R²=0.6693 | RMSE=16.40 | n=4853
#     WITHOUT outliers: R²=0.6109 | RMSE=16.27 | n=4576
#     ΔR² = -0.0583
#
# [6/10] H.-v.-Stephan-Str. 9 / JobRad - Ri. Süd
#     Training WITH outliers...
#     Complete coverage: 6,067/112,321 hours (5.4%)
#     Complete coverage: 6,067/112,321 hours (5.4%)
#     Time frame: 2024-05-22 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (526 days, 6,067 hours)
#     Time frame: 2024-05-22 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (526 days, 6,067 hours)
#     Training WITHOUT outliers (threshold >500)...
#     Training WITHOUT outliers (threshold >500)...
#     Complete coverage: 5,721/112,270 hours (5.1%)
#     Complete coverage: 5,721/112,270 hours (5.1%)
#     Time frame: 2024-05-22 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (526 days, 5,721 hours)
#     Time frame: 2024-05-22 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (526 days, 5,721 hours)
#     WITH outliers:    R²=0.9217 | RMSE=14.54 | n=4853
#     WITHOUT outliers: R²=0.9084 | RMSE=13.92 | n=4576
#     ΔR² = -0.0133
#
# [7/10] H.-v.-Stephan-Str. 9 / JobRad - Ri. Nord
#     Training WITH outliers...
#     WITH outliers:    R²=0.9217 | RMSE=14.54 | n=4853
#     WITHOUT outliers: R²=0.9084 | RMSE=13.92 | n=4576
#     ΔR² = -0.0133
#
# [7/10] H.-v.-Stephan-Str. 9 / JobRad - Ri. Nord
#     Training WITH outliers...
#     Complete coverage: 6,067/112,321 hours (5.4%)
#     Complete coverage: 6,067/112,321 hours (5.4%)
#     Time frame: 2024-05-22 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (526 days, 6,067 hours)
#     Time frame: 2024-05-22 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (526 days, 6,067 hours)
#     Training WITHOUT outliers (threshold >500)...
#     Training WITHOUT outliers (threshold >500)...
#     Complete coverage: 5,721/112,270 hours (5.1%)
#     Complete coverage: 5,721/112,270 hours (5.1%)
#     Time frame: 2024-05-22 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (526 days, 5,721 hours)
#     Time frame: 2024-05-22 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (526 days, 5,721 hours)
#     WITH outliers:    R²=0.8966 | RMSE=16.14 | n=4853
#     WITHOUT outliers: R²=0.8890 | RMSE=15.45 | n=4576
#     ΔR² = -0.0076
#
# [8/10] FR6 Rotteckring / H Theater - Nord + Süd
#     Training WITH outliers...
#     WITH outliers:    R²=0.8966 | RMSE=16.14 | n=4853
#     WITHOUT outliers: R²=0.8890 | RMSE=15.45 | n=4576
#     ΔR² = -0.0076
#
# [8/10] FR6 Rotteckring / H Theater - Nord + Süd
#     Training WITH outliers...
#     Complete coverage: 6,067/112,321 hours (5.4%)
#     Complete coverage: 6,067/112,321 hours (5.4%)
#     Time frame: 2024-05-22 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (526 days, 6,067 hours)
#     Time frame: 2024-05-22 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (526 days, 6,067 hours)
#     Training WITHOUT outliers (threshold >500)...
#     Training WITHOUT outliers (threshold >500)...
#     Complete coverage: 5,721/112,270 hours (5.1%)
#     Complete coverage: 5,721/112,270 hours (5.1%)
#     Time frame: 2024-05-22 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (526 days, 5,721 hours)
#     Time frame: 2024-05-22 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (526 days, 5,721 hours)
#     WITH outliers:    R²=0.9537 | RMSE=64.32 | n=4853
#     WITHOUT outliers: R²=0.9492 | RMSE=61.77 | n=4576
#     ΔR² = -0.0045
#
# [9/10] FR2 Elsässer Str. / Uniklinik einzeln
#     Training WITH outliers...
#     WITH outliers:    R²=0.9537 | RMSE=64.32 | n=4853
#     WITHOUT outliers: R²=0.9492 | RMSE=61.77 | n=4576
#     ΔR² = -0.0045
#
# [9/10] FR2 Elsässer Str. / Uniklinik einzeln
#     Training WITH outliers...
#     Complete coverage: 6,067/112,321 hours (5.4%)
#     Complete coverage: 6,067/112,321 hours (5.4%)
#     Time frame: 2024-05-22 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (526 days, 6,067 hours)
#     Time frame: 2024-05-22 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (526 days, 6,067 hours)
#     Training WITHOUT outliers (threshold >500)...
#     Training WITHOUT outliers (threshold >500)...
#     Complete coverage: 5,721/112,270 hours (5.1%)
#     Complete coverage: 5,721/112,270 hours (5.1%)
#     Time frame: 2024-05-22 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (526 days, 5,721 hours)
#     Time frame: 2024-05-22 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (526 days, 5,721 hours)
#     WITH outliers:    R²=0.9171 | RMSE=34.71 | n=4853
#     WITHOUT outliers: R²=0.8989 | RMSE=33.59 | n=4576
#     ΔR² = -0.0182
#
# [10/10] FR8 Schützenallee / Stadthalle
#     Training WITH outliers...
#     WITH outliers:    R²=0.9171 | RMSE=34.71 | n=4853
#     WITHOUT outliers: R²=0.8989 | RMSE=33.59 | n=4576
#     ΔR² = -0.0182
#
# [10/10] FR8 Schützenallee / Stadthalle
#     Training WITH outliers...
#     Complete coverage: 6,067/112,321 hours (5.4%)
#     Complete coverage: 6,067/112,321 hours (5.4%)
#     Time frame: 2024-05-22 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (526 days, 6,067 hours)
#     Time frame: 2024-05-22 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (526 days, 6,067 hours)
#     Training WITHOUT outliers (threshold >500)...
#     Training WITHOUT outliers (threshold >500)...
#     Complete coverage: 5,721/112,270 hours (5.1%)
#     Complete coverage: 5,721/112,270 hours (5.1%)
#     Time frame: 2024-05-22 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (526 days, 5,721 hours)
#     Time frame: 2024-05-22 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (526 days, 5,721 hours)
#     WITH outliers:    R²=0.9415 | RMSE=27.76 | n=4853
#     WITHOUT outliers: R²=0.9359 | RMSE=26.53 | n=4576
#     ΔR² = -0.0056
#
# --------------------------------------------------------------------------------
# SUMMARY - Stadt Freiburg
# --------------------------------------------------------------------------------
# Successfully trained models for 10 stations
#
# Average R² WITH outliers:    0.8993 ± 0.0953
# Average R² WITHOUT outliers: 0.8818 ± 0.1141
# Average ΔR²:                 -0.0174 ± 0.0195
#
# ================================================================================
# PROCESSING: Stadt Heidelberg
# ================================================================================
#     WITH outliers:    R²=0.9415 | RMSE=27.76 | n=4853
#     WITHOUT outliers: R²=0.9359 | RMSE=26.53 | n=4576
#     ΔR² = -0.0056
#
# --------------------------------------------------------------------------------
# SUMMARY - Stadt Freiburg
# --------------------------------------------------------------------------------
# Successfully trained models for 10 stations
#
# Average R² WITH outliers:    0.8993 ± 0.0953
# Average R² WITHOUT outliers: 0.8818 ± 0.1141
# Average ΔR²:                 -0.0174 ± 0.0195
#
# ================================================================================
# PROCESSING: Stadt Heidelberg
# ================================================================================
#
# Stations: 15
# Records: 858,543
#
# [1/15] Plöck
#     Training WITH outliers...
#
# Stations: 15
# Records: 858,543
#
# [1/15] Plöck
#     Training WITH outliers...
#     Complete coverage: 0/99,956 hours (0.0%)
#     ⊗ No overlapping data with other stations - skipping
#     ⊗ Failed to train model with outliers
#
# [2/15] Gaisbergstraße
#     Training WITH outliers...
#     Complete coverage: 0/99,956 hours (0.0%)
#     ⊗ No overlapping data with other stations - skipping
#     ⊗ Failed to train model with outliers
#
# [2/15] Gaisbergstraße
#     Training WITH outliers...
#     Complete coverage: 0/99,956 hours (0.0%)
#     ⊗ No overlapping data with other stations - skipping
#     ⊗ Failed to train model with outliers
#
# [3/15] Mannheimer Straße
#     Training WITH outliers...
#     Complete coverage: 0/99,956 hours (0.0%)
#     ⊗ No overlapping data with other stations - skipping
#     ⊗ Failed to train model with outliers
#
# [3/15] Mannheimer Straße
#     Training WITH outliers...
#     Complete coverage: 0/99,956 hours (0.0%)
#     ⊗ No overlapping data with other stations - skipping
#     ⊗ Failed to train model with outliers
#
# [4/15] Ernst-Walz-Brücke Querschnitt
#     Training WITH outliers...
#     Complete coverage: 0/99,956 hours (0.0%)
#     ⊗ No overlapping data with other stations - skipping
#     ⊗ Failed to train model with outliers
#
# [4/15] Ernst-Walz-Brücke Querschnitt
#     Training WITH outliers...
#     Complete coverage: 0/99,956 hours (0.0%)
#     ⊗ No overlapping data with other stations - skipping
#     ⊗ Failed to train model with outliers
#
# [5/15] Ernst-Walz-Brücke West - alt
#     Training WITH outliers...
#     Complete coverage: 0/99,956 hours (0.0%)
#     ⊗ No overlapping data with other stations - skipping
#     ⊗ Failed to train model with outliers
#
# [5/15] Ernst-Walz-Brücke West - alt
#     Training WITH outliers...
#     Complete coverage: 0/99,956 hours (0.0%)
#     ⊗ No overlapping data with other stations - skipping
#     ⊗ Failed to train model with outliers
#
# [6/15] Thedor-Heuss-Brücke Querschnitt
#     Training WITH outliers...
#     Complete coverage: 0/99,956 hours (0.0%)
#     ⊗ No overlapping data with other stations - skipping
#     ⊗ Failed to train model with outliers
#
# [6/15] Thedor-Heuss-Brücke Querschnitt
#     Training WITH outliers...
#     Complete coverage: 0/99,956 hours (0.0%)
#     ⊗ No overlapping data with other stations - skipping
#     ⊗ Failed to train model with outliers
#
# [7/15] Rohrbacher Straße Querschnitt
#     Training WITH outliers...
#     Complete coverage: 0/99,956 hours (0.0%)
#     ⊗ No overlapping data with other stations - skipping
#     ⊗ Failed to train model with outliers
#
# [7/15] Rohrbacher Straße Querschnitt
#     Training WITH outliers...
#     Complete coverage: 0/99,956 hours (0.0%)
#     ⊗ No overlapping data with other stations - skipping
#     ⊗ Failed to train model with outliers
#
# [8/15] Liebermannstraße
#     Training WITH outliers...
#     Complete coverage: 0/99,956 hours (0.0%)
#     ⊗ No overlapping data with other stations - skipping
#     ⊗ Failed to train model with outliers
#
# [8/15] Liebermannstraße
#     Training WITH outliers...
#     Complete coverage: 0/99,956 hours (0.0%)
#     ⊗ No overlapping data with other stations - skipping
#     ⊗ Failed to train model with outliers
#
# [9/15] Schlierbacher Landstraße
#     Training WITH outliers...
#     Complete coverage: 0/99,956 hours (0.0%)
#     ⊗ No overlapping data with other stations - skipping
#     ⊗ Failed to train model with outliers
#
# [9/15] Schlierbacher Landstraße
#     Training WITH outliers...
#     Complete coverage: 0/99,956 hours (0.0%)
#     ⊗ No overlapping data with other stations - skipping
#     ⊗ Failed to train model with outliers
#
# [10/15] Ziegelhäuser Landstraße
#     Training WITH outliers...
#     Complete coverage: 0/99,956 hours (0.0%)
#     ⊗ No overlapping data with other stations - skipping
#     ⊗ Failed to train model with outliers
#
# [10/15] Ziegelhäuser Landstraße
#     Training WITH outliers...
#     Complete coverage: 0/99,956 hours (0.0%)
#     ⊗ No overlapping data with other stations - skipping
#     ⊗ Failed to train model with outliers
#
# [11/15] Kurfürstenanlage Querschnitt
#     Training WITH outliers...
#     Complete coverage: 0/99,956 hours (0.0%)
#     ⊗ No overlapping data with other stations - skipping
#     ⊗ Failed to train model with outliers
#
# [11/15] Kurfürstenanlage Querschnitt
#     Training WITH outliers...
#     Complete coverage: 0/99,956 hours (0.0%)
#     ⊗ No overlapping data with other stations - skipping
#     ⊗ Failed to train model with outliers
#
# [12/15] Hardtstraße
#     Training WITH outliers...
#     Complete coverage: 0/99,956 hours (0.0%)
#     ⊗ No overlapping data with other stations - skipping
#     ⊗ Failed to train model with outliers
#
# [12/15] Hardtstraße
#     Training WITH outliers...
#     Complete coverage: 0/99,956 hours (0.0%)
#     ⊗ No overlapping data with other stations - skipping
#     ⊗ Failed to train model with outliers
#
# [13/15] Berliner Straße Querschnitt
#     Training WITH outliers...
#     Complete coverage: 0/99,956 hours (0.0%)
#     ⊗ No overlapping data with other stations - skipping
#     ⊗ Failed to train model with outliers
#
# [13/15] Berliner Straße Querschnitt
#     Training WITH outliers...
#     Complete coverage: 0/99,956 hours (0.0%)
#     ⊗ No overlapping data with other stations - skipping
#     ⊗ Failed to train model with outliers
#
# [14/15] Eppelheimer Str. Querschnitt
#     Training WITH outliers...
#     Complete coverage: 0/99,956 hours (0.0%)
#     ⊗ No overlapping data with other stations - skipping
#     ⊗ Failed to train model with outliers
#
# [14/15] Eppelheimer Str. Querschnitt
#     Training WITH outliers...
#     Complete coverage: 0/99,956 hours (0.0%)
#     ⊗ No overlapping data with other stations - skipping
#     ⊗ Failed to train model with outliers
#
# [15/15] Bahnstadtpromenade
#     Training WITH outliers...
#     Complete coverage: 0/99,956 hours (0.0%)
#     ⊗ No overlapping data with other stations - skipping
#     ⊗ Failed to train model with outliers
#
# [15/15] Bahnstadtpromenade
#     Training WITH outliers...
#     Complete coverage: 0/99,956 hours (0.0%)
#     ⊗ No overlapping data with other stations - skipping
#     ⊗ Failed to train model with outliers
#
# ================================================================================
# PROCESSING: Landeshauptstadt Stuttgart
# ================================================================================
#     Complete coverage: 0/99,956 hours (0.0%)
#     ⊗ No overlapping data with other stations - skipping
#     ⊗ Failed to train model with outliers
#
# ================================================================================
# PROCESSING: Landeshauptstadt Stuttgart
# ================================================================================
#
# Stations: 15
# Records: 873,238
#
# [1/15] König-Karls-Brücke Barometer
#     Training WITH outliers...
#
# Stations: 15
# Records: 873,238
#
# [1/15] König-Karls-Brücke Barometer
#     Training WITH outliers...
#     Complete coverage: 45,157/112,321 hours (40.2%)
#     Complete coverage: 45,157/112,321 hours (40.2%)
#     Time frame: 2020-08-31 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1886 days, 45,157 hours)
#     Time frame: 2020-08-31 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1886 days, 45,157 hours)
#     Training WITHOUT outliers (threshold >500)...
#     Training WITHOUT outliers (threshold >500)...
#     Complete coverage: 45,154/112,321 hours (40.2%)
#     Complete coverage: 45,154/112,321 hours (40.2%)
#     Time frame: 2020-08-31 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1886 days, 45,154 hours)
#     Time frame: 2020-08-31 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1886 days, 45,154 hours)
#     WITH outliers:    R²=0.8407 | RMSE=41.07 | n=36125
#     WITHOUT outliers: R²=0.8400 | RMSE=41.16 | n=36123
#     ΔR² = -0.0007
#
# [2/15] Böblinger Straße
#     Training WITH outliers...
#     WITH outliers:    R²=0.8407 | RMSE=41.07 | n=36125
#     WITHOUT outliers: R²=0.8400 | RMSE=41.16 | n=36123
#     ΔR² = -0.0007
#
# [2/15] Böblinger Straße
#     Training WITH outliers...
#     Complete coverage: 45,157/112,321 hours (40.2%)
#     Complete coverage: 45,157/112,321 hours (40.2%)
#     Time frame: 2020-08-31 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1886 days, 45,157 hours)
#     Time frame: 2020-08-31 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1886 days, 45,157 hours)
#     Training WITHOUT outliers (threshold >500)...
#     Training WITHOUT outliers (threshold >500)...
#     Complete coverage: 45,154/112,321 hours (40.2%)
#     Complete coverage: 45,154/112,321 hours (40.2%)
#     Time frame: 2020-08-31 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1886 days, 45,154 hours)
#     Time frame: 2020-08-31 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1886 days, 45,154 hours)
#     WITH outliers:    R²=0.8460 | RMSE=21.10 | n=36125
#     WITHOUT outliers: R²=0.8460 | RMSE=21.10 | n=36123
#     ΔR² = -0.0000
#
# [3/15] Taubenheimstraße
#     Training WITH outliers...
#     WITH outliers:    R²=0.8460 | RMSE=21.10 | n=36125
#     WITHOUT outliers: R²=0.8460 | RMSE=21.10 | n=36123
#     ΔR² = -0.0000
#
# [3/15] Taubenheimstraße
#     Training WITH outliers...
#     Complete coverage: 45,157/112,321 hours (40.2%)
#     Complete coverage: 45,157/112,321 hours (40.2%)
#     Time frame: 2020-08-31 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1886 days, 45,157 hours)
#     Time frame: 2020-08-31 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1886 days, 45,157 hours)
#     Training WITHOUT outliers (threshold >500)...
#     Training WITHOUT outliers (threshold >500)...
#     Complete coverage: 45,154/112,321 hours (40.2%)
#     Complete coverage: 45,154/112,321 hours (40.2%)
#     Time frame: 2020-08-31 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1886 days, 45,154 hours)
#     Time frame: 2020-08-31 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1886 days, 45,154 hours)
#     WITH outliers:    R²=0.5070 | RMSE=7.74 | n=36125
#     WITHOUT outliers: R²=0.5323 | RMSE=7.54 | n=36123
#     ΔR² = +0.0253
#
# [4/15] Waiblinger Straße
#     Training WITH outliers...
#     WITH outliers:    R²=0.5070 | RMSE=7.74 | n=36125
#     WITHOUT outliers: R²=0.5323 | RMSE=7.54 | n=36123
#     ΔR² = +0.0253
#
# [4/15] Waiblinger Straße
#     Training WITH outliers...
#     Complete coverage: 45,157/112,321 hours (40.2%)
#     Complete coverage: 45,157/112,321 hours (40.2%)
#     Time frame: 2020-08-31 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1886 days, 45,157 hours)
#     Time frame: 2020-08-31 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1886 days, 45,157 hours)
#     Training WITHOUT outliers (threshold >500)...
#     Training WITHOUT outliers (threshold >500)...
#     Complete coverage: 45,154/112,321 hours (40.2%)
#     Complete coverage: 45,154/112,321 hours (40.2%)
#     Time frame: 2020-08-31 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1886 days, 45,154 hours)
#     Time frame: 2020-08-31 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1886 days, 45,154 hours)
#     WITH outliers:    R²=0.8532 | RMSE=4.69 | n=36125
#     WITHOUT outliers: R²=0.8533 | RMSE=4.68 | n=36123
#     ΔR² = +0.0001
#
# [5/15] Samaraweg
#     Training WITH outliers...
#     WITH outliers:    R²=0.8532 | RMSE=4.69 | n=36125
#     WITHOUT outliers: R²=0.8533 | RMSE=4.68 | n=36123
#     ΔR² = +0.0001
#
# [5/15] Samaraweg
#     Training WITH outliers...
#     Complete coverage: 45,157/112,321 hours (40.2%)
#     Complete coverage: 45,157/112,321 hours (40.2%)
#     Time frame: 2020-08-31 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1886 days, 45,157 hours)
#     Time frame: 2020-08-31 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1886 days, 45,157 hours)
#     Training WITHOUT outliers (threshold >500)...
#     Training WITHOUT outliers (threshold >500)...
#     Complete coverage: 45,154/112,321 hours (40.2%)
#     Complete coverage: 45,154/112,321 hours (40.2%)
#     Time frame: 2020-08-31 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1886 days, 45,154 hours)
#     Time frame: 2020-08-31 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1886 days, 45,154 hours)
#     WITH outliers:    R²=0.8604 | RMSE=25.80 | n=36125
#     WITHOUT outliers: R²=0.8613 | RMSE=25.72 | n=36123
#     ΔR² = +0.0010
#
# [6/15] Waldburgstraße
#     Training WITH outliers...
#     WITH outliers:    R²=0.8604 | RMSE=25.80 | n=36125
#     WITHOUT outliers: R²=0.8613 | RMSE=25.72 | n=36123
#     ΔR² = +0.0010
#
# [6/15] Waldburgstraße
#     Training WITH outliers...
#     Complete coverage: 45,157/112,321 hours (40.2%)
#     Complete coverage: 45,157/112,321 hours (40.2%)
#     Time frame: 2020-08-31 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1886 days, 45,157 hours)
#     Time frame: 2020-08-31 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1886 days, 45,157 hours)
#     Training WITHOUT outliers (threshold >500)...
#     Training WITHOUT outliers (threshold >500)...
#     Complete coverage: 45,154/112,321 hours (40.2%)
#     Complete coverage: 45,154/112,321 hours (40.2%)
#     Time frame: 2020-08-31 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1886 days, 45,154 hours)
#     Time frame: 2020-08-31 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1886 days, 45,154 hours)
#     WITH outliers:    R²=0.8347 | RMSE=10.42 | n=36125
#     WITHOUT outliers: R²=0.8357 | RMSE=10.39 | n=36123
#     ΔR² = +0.0011
#
# [7/15] Kremmlerstraße
#     Training WITH outliers...
#     WITH outliers:    R²=0.8347 | RMSE=10.42 | n=36125
#     WITHOUT outliers: R²=0.8357 | RMSE=10.39 | n=36123
#     ΔR² = +0.0011
#
# [7/15] Kremmlerstraße
#     Training WITH outliers...
#     Complete coverage: 45,157/112,321 hours (40.2%)
#     Complete coverage: 45,157/112,321 hours (40.2%)
#     Time frame: 2020-08-31 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1886 days, 45,157 hours)
#     Time frame: 2020-08-31 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1886 days, 45,157 hours)
#     Training WITHOUT outliers (threshold >500)...
#     Training WITHOUT outliers (threshold >500)...
#     Complete coverage: 45,154/112,321 hours (40.2%)
#     Complete coverage: 45,154/112,321 hours (40.2%)
#     Time frame: 2020-08-31 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1886 days, 45,154 hours)
#     Time frame: 2020-08-31 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1886 days, 45,154 hours)
#     WITH outliers:    R²=0.8883 | RMSE=13.06 | n=36125
#     WITHOUT outliers: R²=0.8887 | RMSE=13.04 | n=36123
#     ΔR² = +0.0005
#
# [8/15] Kirchheimer Straße
#     Training WITH outliers...
#     WITH outliers:    R²=0.8883 | RMSE=13.06 | n=36125
#     WITHOUT outliers: R²=0.8887 | RMSE=13.04 | n=36123
#     ΔR² = +0.0005
#
# [8/15] Kirchheimer Straße
#     Training WITH outliers...
#     Complete coverage: 45,157/112,321 hours (40.2%)
#     Complete coverage: 45,157/112,321 hours (40.2%)
#     Time frame: 2020-08-31 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1886 days, 45,157 hours)
#     Time frame: 2020-08-31 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1886 days, 45,157 hours)
#     Training WITHOUT outliers (threshold >500)...
#     Training WITHOUT outliers (threshold >500)...
#     Complete coverage: 45,154/112,321 hours (40.2%)
#     Complete coverage: 45,154/112,321 hours (40.2%)
#     Time frame: 2020-08-31 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1886 days, 45,154 hours)
#     Time frame: 2020-08-31 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1886 days, 45,154 hours)
#     WITH outliers:    R²=0.9119 | RMSE=7.86 | n=36125
#     WITHOUT outliers: R²=0.9124 | RMSE=7.84 | n=36123
#     ΔR² = +0.0005
#
# [9/15] Stuttgarter Straße
#     Training WITH outliers...
#     WITH outliers:    R²=0.9119 | RMSE=7.86 | n=36125
#     WITHOUT outliers: R²=0.9124 | RMSE=7.84 | n=36123
#     ΔR² = +0.0005
#
# [9/15] Stuttgarter Straße
#     Training WITH outliers...
#     Complete coverage: 45,157/112,321 hours (40.2%)
#     Complete coverage: 45,157/112,321 hours (40.2%)
#     Time frame: 2020-08-31 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1886 days, 45,157 hours)
#     Time frame: 2020-08-31 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1886 days, 45,157 hours)
#     Training WITHOUT outliers (threshold >500)...
#     Training WITHOUT outliers (threshold >500)...
#     Complete coverage: 45,154/112,321 hours (40.2%)
#     Complete coverage: 45,154/112,321 hours (40.2%)
#     Time frame: 2020-08-31 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1886 days, 45,154 hours)
#     Time frame: 2020-08-31 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1886 days, 45,154 hours)
#     WITH outliers:    R²=0.7707 | RMSE=8.89 | n=36125
#     WITHOUT outliers: R²=0.7706 | RMSE=8.89 | n=36123
#     ΔR² = -0.0001
#
# [10/15] Solitudestraße
#     Training WITH outliers...
#     WITH outliers:    R²=0.7707 | RMSE=8.89 | n=36125
#     WITHOUT outliers: R²=0.7706 | RMSE=8.89 | n=36123
#     ΔR² = -0.0001
#
# [10/15] Solitudestraße
#     Training WITH outliers...
#     Complete coverage: 45,157/112,321 hours (40.2%)
#     Complete coverage: 45,157/112,321 hours (40.2%)
#     Time frame: 2020-08-31 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1886 days, 45,157 hours)
#     Time frame: 2020-08-31 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1886 days, 45,157 hours)
#     Training WITHOUT outliers (threshold >500)...
#     Training WITHOUT outliers (threshold >500)...
#     Complete coverage: 45,154/112,321 hours (40.2%)
#     Complete coverage: 45,154/112,321 hours (40.2%)
#     Time frame: 2020-08-31 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1886 days, 45,154 hours)
#     Time frame: 2020-08-31 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1886 days, 45,154 hours)
#     WITH outliers:    R²=0.8214 | RMSE=8.30 | n=36125
#     WITHOUT outliers: R²=0.8216 | RMSE=8.30 | n=36123
#     ΔR² = +0.0001
#
# [11/15] Am Kräherwald
#     Training WITH outliers...
#     WITH outliers:    R²=0.8214 | RMSE=8.30 | n=36125
#     WITHOUT outliers: R²=0.8216 | RMSE=8.30 | n=36123
#     ΔR² = +0.0001
#
# [11/15] Am Kräherwald
#     Training WITH outliers...
#     Complete coverage: 45,157/112,321 hours (40.2%)
#     Complete coverage: 45,157/112,321 hours (40.2%)
#     Time frame: 2020-08-31 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1886 days, 45,157 hours)
#     Time frame: 2020-08-31 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1886 days, 45,157 hours)
#     Training WITHOUT outliers (threshold >500)...
#     Training WITHOUT outliers (threshold >500)...
#     Complete coverage: 45,154/112,321 hours (40.2%)
#     Complete coverage: 45,154/112,321 hours (40.2%)
#     Time frame: 2020-08-31 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1886 days, 45,154 hours)
#     Time frame: 2020-08-31 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1886 days, 45,154 hours)
#     WITH outliers:    R²=0.8670 | RMSE=6.75 | n=36125
#     WITHOUT outliers: R²=0.8669 | RMSE=6.75 | n=36123
#     ΔR² = -0.0002
#
# [12/15] Inselstraße
#     Training WITH outliers...
#     WITH outliers:    R²=0.8670 | RMSE=6.75 | n=36125
#     WITHOUT outliers: R²=0.8669 | RMSE=6.75 | n=36123
#     ΔR² = -0.0002
#
# [12/15] Inselstraße
#     Training WITH outliers...
#     Complete coverage: 45,157/112,321 hours (40.2%)
#     Complete coverage: 45,157/112,321 hours (40.2%)
#     Time frame: 2020-08-31 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1886 days, 45,157 hours)
#     Time frame: 2020-08-31 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1886 days, 45,157 hours)
#     Training WITHOUT outliers (threshold >500)...
#     Training WITHOUT outliers (threshold >500)...
#     Complete coverage: 45,154/112,321 hours (40.2%)
#     Complete coverage: 45,154/112,321 hours (40.2%)
#     Time frame: 2020-08-31 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1886 days, 45,154 hours)
#     Time frame: 2020-08-31 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1886 days, 45,154 hours)
#     WITH outliers:    R²=0.9057 | RMSE=13.20 | n=36125
#     WITHOUT outliers: R²=0.9058 | RMSE=13.20 | n=36123
#     ΔR² = +0.0001
#
# [13/15] Neckartalstraße
#     Training WITH outliers...
#     WITH outliers:    R²=0.9057 | RMSE=13.20 | n=36125
#     WITHOUT outliers: R²=0.9058 | RMSE=13.20 | n=36123
#     ΔR² = +0.0001
#
# [13/15] Neckartalstraße
#     Training WITH outliers...
#     Complete coverage: 45,157/112,321 hours (40.2%)
#     Complete coverage: 45,157/112,321 hours (40.2%)
#     Time frame: 2020-08-31 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1886 days, 45,157 hours)
#     Time frame: 2020-08-31 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1886 days, 45,157 hours)
#     Training WITHOUT outliers (threshold >500)...
#     Training WITHOUT outliers (threshold >500)...
#     Complete coverage: 45,154/112,321 hours (40.2%)
#     Complete coverage: 45,154/112,321 hours (40.2%)
#     Time frame: 2020-08-31 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1886 days, 45,154 hours)
#     Time frame: 2020-08-31 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1886 days, 45,154 hours)
#     WITH outliers:    R²=0.3869 | RMSE=13.25 | n=36125
#     WITHOUT outliers: R²=0.3803 | RMSE=13.32 | n=36123
#     ΔR² = -0.0066
#
# [14/15] Lautenschlager Straße
#     Training WITH outliers...
#     WITH outliers:    R²=0.3869 | RMSE=13.25 | n=36125
#     WITHOUT outliers: R²=0.3803 | RMSE=13.32 | n=36123
#     ΔR² = -0.0066
#
# [14/15] Lautenschlager Straße
#     Training WITH outliers...
#     Complete coverage: 45,157/112,321 hours (40.2%)
#     Complete coverage: 45,157/112,321 hours (40.2%)
#     Time frame: 2020-08-31 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1886 days, 45,157 hours)
#     Time frame: 2020-08-31 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1886 days, 45,157 hours)
#     Training WITHOUT outliers (threshold >500)...
#     Training WITHOUT outliers (threshold >500)...
#     Complete coverage: 45,154/112,321 hours (40.2%)
#     Complete coverage: 45,154/112,321 hours (40.2%)
#     Time frame: 2020-08-31 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1886 days, 45,154 hours)
#     Time frame: 2020-08-31 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1886 days, 45,154 hours)
#     WITH outliers:    R²=0.8215 | RMSE=20.90 | n=36125
#     WITHOUT outliers: R²=0.8215 | RMSE=20.90 | n=36123
#     ΔR² = -0.0000
#
# [15/15] Tübinger Straße
#     Training WITH outliers...
#     WITH outliers:    R²=0.8215 | RMSE=20.90 | n=36125
#     WITHOUT outliers: R²=0.8215 | RMSE=20.90 | n=36123
#     ΔR² = -0.0000
#
# [15/15] Tübinger Straße
#     Training WITH outliers...
#     Complete coverage: 45,157/112,321 hours (40.2%)
#     Complete coverage: 45,157/112,321 hours (40.2%)
#     Time frame: 2020-08-31 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1886 days, 45,157 hours)
#     Time frame: 2020-08-31 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1886 days, 45,157 hours)
#     Training WITHOUT outliers (threshold >500)...
#     Training WITHOUT outliers (threshold >500)...
#     Complete coverage: 45,154/112,321 hours (40.2%)
#     Complete coverage: 45,154/112,321 hours (40.2%)
#     Time frame: 2020-08-31 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1886 days, 45,154 hours)
#     Time frame: 2020-08-31 22:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1886 days, 45,154 hours)
#     WITH outliers:    R²=0.9190 | RMSE=29.42 | n=36125
#     WITHOUT outliers: R²=0.9190 | RMSE=29.40 | n=36123
#     ΔR² = +0.0001
#
# --------------------------------------------------------------------------------
# SUMMARY - Landeshauptstadt Stuttgart
# --------------------------------------------------------------------------------
# Successfully trained models for 15 stations
#
# Average R² WITH outliers:    0.8023 ± 0.1511
# Average R² WITHOUT outliers: 0.8037 ± 0.1491
# Average ΔR²:                 +0.0014 ± 0.0068
#
# ================================================================================
# PROCESSING: Stadt Mannheim
# ================================================================================
#     WITH outliers:    R²=0.9190 | RMSE=29.42 | n=36125
#     WITHOUT outliers: R²=0.9190 | RMSE=29.40 | n=36123
#     ΔR² = +0.0001
#
# --------------------------------------------------------------------------------
# SUMMARY - Landeshauptstadt Stuttgart
# --------------------------------------------------------------------------------
# Successfully trained models for 15 stations
#
# Average R² WITH outliers:    0.8023 ± 0.1511
# Average R² WITHOUT outliers: 0.8037 ± 0.1491
# Average ΔR²:                 +0.0014 ± 0.0068
#
# ================================================================================
# PROCESSING: Stadt Mannheim
# ================================================================================
#
# Stations: 14
# Records: 677,648
#
# [1/14] Renzstraße
#     Training WITH outliers...
#
# Stations: 14
# Records: 677,648
#
# [1/14] Renzstraße
#     Training WITH outliers...
#     Complete coverage: 19,710/101,550 hours (19.4%)
#     Complete coverage: 19,710/101,550 hours (19.4%)
#     Time frame: 2023-01-25 15:00:00+00:00 to 2025-10-31 00:00:00+00:00 (1009 days, 19,710 hours)
#     Time frame: 2023-01-25 15:00:00+00:00 to 2025-10-31 00:00:00+00:00 (1009 days, 19,710 hours)
#     Training WITHOUT outliers (threshold >500)...
#     Training WITHOUT outliers (threshold >500)...
#     Complete coverage: 19,709/101,550 hours (19.4%)
#     Complete coverage: 19,709/101,550 hours (19.4%)
#     Time frame: 2023-01-25 15:00:00+00:00 to 2025-10-31 00:00:00+00:00 (1009 days, 19,709 hours)
#     Time frame: 2023-01-25 15:00:00+00:00 to 2025-10-31 00:00:00+00:00 (1009 days, 19,709 hours)
#     WITH outliers:    R²=0.9650 | RMSE=24.98 | n=15768
#     WITHOUT outliers: R²=0.9652 | RMSE=24.93 | n=15767
#     ΔR² = +0.0002
#
# [2/14] Kurpfalzbrücke
#     Training WITH outliers...
#     WITH outliers:    R²=0.9650 | RMSE=24.98 | n=15768
#     WITHOUT outliers: R²=0.9652 | RMSE=24.93 | n=15767
#     ΔR² = +0.0002
#
# [2/14] Kurpfalzbrücke
#     Training WITH outliers...
#     Complete coverage: 19,710/101,550 hours (19.4%)
#     Complete coverage: 19,710/101,550 hours (19.4%)
#     Time frame: 2023-01-25 15:00:00+00:00 to 2025-10-31 00:00:00+00:00 (1009 days, 19,710 hours)
#     Time frame: 2023-01-25 15:00:00+00:00 to 2025-10-31 00:00:00+00:00 (1009 days, 19,710 hours)
#     Training WITHOUT outliers (threshold >500)...
#     Training WITHOUT outliers (threshold >500)...
#     Complete coverage: 19,709/101,550 hours (19.4%)
#     Complete coverage: 19,709/101,550 hours (19.4%)
#     Time frame: 2023-01-25 15:00:00+00:00 to 2025-10-31 00:00:00+00:00 (1009 days, 19,709 hours)
#     Time frame: 2023-01-25 15:00:00+00:00 to 2025-10-31 00:00:00+00:00 (1009 days, 19,709 hours)
#     WITH outliers:    R²=0.5677 | RMSE=93.48 | n=15768
#     WITHOUT outliers: R²=0.5690 | RMSE=93.35 | n=15767
#     ΔR² = +0.0013
#
# [3/14] Jungbuschbrücke
#     Training WITH outliers...
#     WITH outliers:    R²=0.5677 | RMSE=93.48 | n=15768
#     WITHOUT outliers: R²=0.5690 | RMSE=93.35 | n=15767
#     ΔR² = +0.0013
#
# [3/14] Jungbuschbrücke
#     Training WITH outliers...
#     Complete coverage: 19,710/101,550 hours (19.4%)
#     Complete coverage: 19,710/101,550 hours (19.4%)
#     Time frame: 2023-01-25 15:00:00+00:00 to 2025-10-31 00:00:00+00:00 (1009 days, 19,710 hours)
#     Time frame: 2023-01-25 15:00:00+00:00 to 2025-10-31 00:00:00+00:00 (1009 days, 19,710 hours)
#     Training WITHOUT outliers (threshold >500)...
#     Training WITHOUT outliers (threshold >500)...
#     Complete coverage: 19,709/101,550 hours (19.4%)
#     Complete coverage: 19,709/101,550 hours (19.4%)
#     Time frame: 2023-01-25 15:00:00+00:00 to 2025-10-31 00:00:00+00:00 (1009 days, 19,709 hours)
#     Time frame: 2023-01-25 15:00:00+00:00 to 2025-10-31 00:00:00+00:00 (1009 days, 19,709 hours)
#     WITH outliers:    R²=0.8304 | RMSE=16.97 | n=15768
#     WITHOUT outliers: R²=0.8272 | RMSE=17.13 | n=15767
#     ΔR² = -0.0032
#
# [4/14] Konrad-Adenauer-Brücke
#     Training WITH outliers...
#     WITH outliers:    R²=0.8304 | RMSE=16.97 | n=15768
#     WITHOUT outliers: R²=0.8272 | RMSE=17.13 | n=15767
#     ΔR² = -0.0032
#
# [4/14] Konrad-Adenauer-Brücke
#     Training WITH outliers...
#     Complete coverage: 19,710/101,550 hours (19.4%)
#     Complete coverage: 19,710/101,550 hours (19.4%)
#     Time frame: 2023-01-25 15:00:00+00:00 to 2025-10-31 00:00:00+00:00 (1009 days, 19,710 hours)
#     Time frame: 2023-01-25 15:00:00+00:00 to 2025-10-31 00:00:00+00:00 (1009 days, 19,710 hours)
#     Training WITHOUT outliers (threshold >500)...
#     Training WITHOUT outliers (threshold >500)...
#     Complete coverage: 19,709/101,550 hours (19.4%)
#     Complete coverage: 19,709/101,550 hours (19.4%)
#     Time frame: 2023-01-25 15:00:00+00:00 to 2025-10-31 00:00:00+00:00 (1009 days, 19,709 hours)
#     Time frame: 2023-01-25 15:00:00+00:00 to 2025-10-31 00:00:00+00:00 (1009 days, 19,709 hours)
#     WITH outliers:    R²=0.9565 | RMSE=18.48 | n=15768
#     WITHOUT outliers: R²=0.9565 | RMSE=18.48 | n=15767
#     ΔR² = +0.0000
#
# [5/14] Lindenhofüberführung
#     Training WITH outliers...
#     WITH outliers:    R²=0.9565 | RMSE=18.48 | n=15768
#     WITHOUT outliers: R²=0.9565 | RMSE=18.48 | n=15767
#     ΔR² = +0.0000
#
# [5/14] Lindenhofüberführung
#     Training WITH outliers...
#     Complete coverage: 19,710/101,550 hours (19.4%)
#     Complete coverage: 19,710/101,550 hours (19.4%)
#     Time frame: 2023-01-25 15:00:00+00:00 to 2025-10-31 00:00:00+00:00 (1009 days, 19,710 hours)
#     Time frame: 2023-01-25 15:00:00+00:00 to 2025-10-31 00:00:00+00:00 (1009 days, 19,710 hours)
#     Training WITHOUT outliers (threshold >500)...
#     Training WITHOUT outliers (threshold >500)...
#     Complete coverage: 19,709/101,550 hours (19.4%)
#     Complete coverage: 19,709/101,550 hours (19.4%)
#     Time frame: 2023-01-25 15:00:00+00:00 to 2025-10-31 00:00:00+00:00 (1009 days, 19,709 hours)
#     Time frame: 2023-01-25 15:00:00+00:00 to 2025-10-31 00:00:00+00:00 (1009 days, 19,709 hours)
#     WITH outliers:    R²=0.2558 | RMSE=46.90 | n=15768
#     WITHOUT outliers: R²=0.2624 | RMSE=46.69 | n=15767
#     ΔR² = +0.0066
#
# [6/14] Neckarauer Übergang -Schwetzinger Str.
#     Training WITH outliers...
#     WITH outliers:    R²=0.2558 | RMSE=46.90 | n=15768
#     WITHOUT outliers: R²=0.2624 | RMSE=46.69 | n=15767
#     ΔR² = +0.0066
#
# [6/14] Neckarauer Übergang -Schwetzinger Str.
#     Training WITH outliers...
#     Complete coverage: 19,710/101,550 hours (19.4%)
#     Complete coverage: 19,710/101,550 hours (19.4%)
#     Time frame: 2023-01-25 15:00:00+00:00 to 2025-10-31 00:00:00+00:00 (1009 days, 19,710 hours)
#     Time frame: 2023-01-25 15:00:00+00:00 to 2025-10-31 00:00:00+00:00 (1009 days, 19,710 hours)
#     Training WITHOUT outliers (threshold >500)...
#     Training WITHOUT outliers (threshold >500)...
#     Complete coverage: 19,709/101,550 hours (19.4%)
#     Complete coverage: 19,709/101,550 hours (19.4%)
#     Time frame: 2023-01-25 15:00:00+00:00 to 2025-10-31 00:00:00+00:00 (1009 days, 19,709 hours)
#     Time frame: 2023-01-25 15:00:00+00:00 to 2025-10-31 00:00:00+00:00 (1009 days, 19,709 hours)
#     WITH outliers:    R²=0.9123 | RMSE=10.97 | n=15768
#     WITHOUT outliers: R²=0.9124 | RMSE=10.96 | n=15767
#     ΔR² = +0.0001
#
# [7/14] Schlosspark Lindenhof (Richtung Jugendherberge)
#     Training WITH outliers...
#     WITH outliers:    R²=0.9123 | RMSE=10.97 | n=15768
#     WITHOUT outliers: R²=0.9124 | RMSE=10.96 | n=15767
#     ΔR² = +0.0001
#
# [7/14] Schlosspark Lindenhof (Richtung Jugendherberge)
#     Training WITH outliers...
#     Complete coverage: 19,710/101,550 hours (19.4%)
#     Complete coverage: 19,710/101,550 hours (19.4%)
#     Time frame: 2023-01-25 15:00:00+00:00 to 2025-10-31 00:00:00+00:00 (1009 days, 19,710 hours)
#     Time frame: 2023-01-25 15:00:00+00:00 to 2025-10-31 00:00:00+00:00 (1009 days, 19,710 hours)
#     Training WITHOUT outliers (threshold >500)...
#     Training WITHOUT outliers (threshold >500)...
#     Complete coverage: 19,709/101,550 hours (19.4%)
#     Complete coverage: 19,709/101,550 hours (19.4%)
#     Time frame: 2023-01-25 15:00:00+00:00 to 2025-10-31 00:00:00+00:00 (1009 days, 19,709 hours)
#     Time frame: 2023-01-25 15:00:00+00:00 to 2025-10-31 00:00:00+00:00 (1009 days, 19,709 hours)
#     WITH outliers:    R²=0.9535 | RMSE=12.53 | n=15768
#     WITHOUT outliers: R²=0.9537 | RMSE=12.51 | n=15767
#     ΔR² = +0.0002
#
# [8/14] Feudenheimstr. stadtauswärts
#     Training WITH outliers...
#     WITH outliers:    R²=0.9535 | RMSE=12.53 | n=15768
#     WITHOUT outliers: R²=0.9537 | RMSE=12.51 | n=15767
#     ΔR² = +0.0002
#
# [8/14] Feudenheimstr. stadtauswärts
#     Training WITH outliers...
#     Complete coverage: 19,710/101,550 hours (19.4%)
#     Complete coverage: 19,710/101,550 hours (19.4%)
#     Time frame: 2023-01-25 15:00:00+00:00 to 2025-10-31 00:00:00+00:00 (1009 days, 19,710 hours)
#     Time frame: 2023-01-25 15:00:00+00:00 to 2025-10-31 00:00:00+00:00 (1009 days, 19,710 hours)
#     Training WITHOUT outliers (threshold >500)...
#     Training WITHOUT outliers (threshold >500)...
#     Complete coverage: 19,709/101,550 hours (19.4%)
#     Complete coverage: 19,709/101,550 hours (19.4%)
#     Time frame: 2023-01-25 15:00:00+00:00 to 2025-10-31 00:00:00+00:00 (1009 days, 19,709 hours)
#     Time frame: 2023-01-25 15:00:00+00:00 to 2025-10-31 00:00:00+00:00 (1009 days, 19,709 hours)
#     WITH outliers:    R²=0.7334 | RMSE=12.09 | n=15768
#     WITHOUT outliers: R²=0.7334 | RMSE=12.09 | n=15767
#     ΔR² = -0.0000
#
# [9/14] Feudenheimerstr. stadteinwärts
#     Training WITH outliers...
#     WITH outliers:    R²=0.7334 | RMSE=12.09 | n=15768
#     WITHOUT outliers: R²=0.7334 | RMSE=12.09 | n=15767
#     ΔR² = -0.0000
#
# [9/14] Feudenheimerstr. stadteinwärts
#     Training WITH outliers...
#     Complete coverage: 19,710/101,550 hours (19.4%)
#     Complete coverage: 19,710/101,550 hours (19.4%)
#     Time frame: 2023-01-25 15:00:00+00:00 to 2025-10-31 00:00:00+00:00 (1009 days, 19,710 hours)
#     Time frame: 2023-01-25 15:00:00+00:00 to 2025-10-31 00:00:00+00:00 (1009 days, 19,710 hours)
#     Training WITHOUT outliers (threshold >500)...
#     Training WITHOUT outliers (threshold >500)...
#     Complete coverage: 19,709/101,550 hours (19.4%)
#     Complete coverage: 19,709/101,550 hours (19.4%)
#     Time frame: 2023-01-25 15:00:00+00:00 to 2025-10-31 00:00:00+00:00 (1009 days, 19,709 hours)
#     Time frame: 2023-01-25 15:00:00+00:00 to 2025-10-31 00:00:00+00:00 (1009 days, 19,709 hours)
#     WITH outliers:    R²=0.7868 | RMSE=8.23 | n=15768
#     WITHOUT outliers: R²=0.7868 | RMSE=8.23 | n=15767
#     ΔR² = +0.0000
#
# [10/14] Luzenbergstr.
#     Training WITH outliers...
#     WITH outliers:    R²=0.7868 | RMSE=8.23 | n=15768
#     WITHOUT outliers: R²=0.7868 | RMSE=8.23 | n=15767
#     ΔR² = +0.0000
#
# [10/14] Luzenbergstr.
#     Training WITH outliers...
#     Complete coverage: 19,710/101,550 hours (19.4%)
#     Complete coverage: 19,710/101,550 hours (19.4%)
#     Time frame: 2023-01-25 15:00:00+00:00 to 2025-10-31 00:00:00+00:00 (1009 days, 19,710 hours)
#     Time frame: 2023-01-25 15:00:00+00:00 to 2025-10-31 00:00:00+00:00 (1009 days, 19,710 hours)
#     Training WITHOUT outliers (threshold >500)...
#     Training WITHOUT outliers (threshold >500)...
#     Complete coverage: 19,709/101,550 hours (19.4%)
#     Complete coverage: 19,709/101,550 hours (19.4%)
#     Time frame: 2023-01-25 15:00:00+00:00 to 2025-10-31 00:00:00+00:00 (1009 days, 19,709 hours)
#     Time frame: 2023-01-25 15:00:00+00:00 to 2025-10-31 00:00:00+00:00 (1009 days, 19,709 hours)
#     WITH outliers:    R²=0.8495 | RMSE=9.84 | n=15768
#     WITHOUT outliers: R²=0.8661 | RMSE=9.28 | n=15767
#     ΔR² = +0.0167
#
# [11/14] B38. RI. AUS
#     Training WITH outliers...
#     WITH outliers:    R²=0.8495 | RMSE=9.84 | n=15768
#     WITHOUT outliers: R²=0.8661 | RMSE=9.28 | n=15767
#     ΔR² = +0.0167
#
# [11/14] B38. RI. AUS
#     Training WITH outliers...
#     Complete coverage: 19,710/101,550 hours (19.4%)
#     Complete coverage: 19,710/101,550 hours (19.4%)
#     Time frame: 2023-01-25 15:00:00+00:00 to 2025-10-31 00:00:00+00:00 (1009 days, 19,710 hours)
#     Time frame: 2023-01-25 15:00:00+00:00 to 2025-10-31 00:00:00+00:00 (1009 days, 19,710 hours)
#     Training WITHOUT outliers (threshold >500)...
#     Training WITHOUT outliers (threshold >500)...
#     Complete coverage: 19,709/101,550 hours (19.4%)
#     Complete coverage: 19,709/101,550 hours (19.4%)
#     Time frame: 2023-01-25 15:00:00+00:00 to 2025-10-31 00:00:00+00:00 (1009 days, 19,709 hours)
#     Time frame: 2023-01-25 15:00:00+00:00 to 2025-10-31 00:00:00+00:00 (1009 days, 19,709 hours)
#     WITH outliers:    R²=-0.2331 | RMSE=35.09 | n=15768
#     WITHOUT outliers: R²=-0.2263 | RMSE=34.99 | n=15767
#     ΔR² = +0.0068
#
# [12/14] Theodor-Heuss-Anlage. RI. IN.
#     Training WITH outliers...
#     WITH outliers:    R²=-0.2331 | RMSE=35.09 | n=15768
#     WITHOUT outliers: R²=-0.2263 | RMSE=34.99 | n=15767
#     ΔR² = +0.0068
#
# [12/14] Theodor-Heuss-Anlage. RI. IN.
#     Training WITH outliers...
#     Complete coverage: 19,710/101,550 hours (19.4%)
# ...
#     Time frame: 2021-02-09 10:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1724 days, 39,394 hours)
#     Time frame: 2021-02-09 10:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1724 days, 39,394 hours)
#     Training WITHOUT outliers (threshold >500)...
#     Training WITHOUT outliers (threshold >500)...
#     Complete coverage: 39,386/70,852 hours (55.6%)
#     Complete coverage: 39,386/70,852 hours (55.6%)
#     Time frame: 2021-02-09 10:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1724 days, 39,386 hours)
#     Time frame: 2021-02-09 10:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1724 days, 39,386 hours)
#     WITH outliers:    R²=0.9132 | RMSE=7.01 | n=31515
#     WITHOUT outliers: R²=0.9133 | RMSE=7.01 | n=31508
#     ΔR² = +0.0000
#
# [11/15] Aldinger Straße
#     Training WITH outliers...
#     WITH outliers:    R²=0.9132 | RMSE=7.01 | n=31515
#     WITHOUT outliers: R²=0.9133 | RMSE=7.01 | n=31508
#     ΔR² = +0.0000
#
# [11/15] Aldinger Straße
#     Training WITH outliers...
#     Complete coverage: 39,394/70,852 hours (55.6%)
#     Complete coverage: 39,394/70,852 hours (55.6%)
#     Time frame: 2021-02-09 10:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1724 days, 39,394 hours)
#     Time frame: 2021-02-09 10:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1724 days, 39,394 hours)
#     Training WITHOUT outliers (threshold >500)...
#     Training WITHOUT outliers (threshold >500)...
#     Complete coverage: 39,386/70,852 hours (55.6%)
#     Complete coverage: 39,386/70,852 hours (55.6%)
#     Time frame: 2021-02-09 10:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1724 days, 39,386 hours)
#     Time frame: 2021-02-09 10:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1724 days, 39,386 hours)
#     WITH outliers:    R²=0.8762 | RMSE=5.31 | n=31515
#     WITHOUT outliers: R²=0.8761 | RMSE=5.31 | n=31508
#     ΔR² = -0.0000
#
# [12/15] Bottwartalstraße
#     Training WITH outliers...
#     WITH outliers:    R²=0.8762 | RMSE=5.31 | n=31515
#     WITHOUT outliers: R²=0.8761 | RMSE=5.31 | n=31508
#     ΔR² = -0.0000
#
# [12/15] Bottwartalstraße
#     Training WITH outliers...
#     Complete coverage: 39,394/70,852 hours (55.6%)
#     Complete coverage: 39,394/70,852 hours (55.6%)
#     Time frame: 2021-02-09 10:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1724 days, 39,394 hours)
#     Time frame: 2021-02-09 10:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1724 days, 39,394 hours)
#     Training WITHOUT outliers (threshold >500)...
#     Training WITHOUT outliers (threshold >500)...
#     Complete coverage: 39,386/70,852 hours (55.6%)
#     Complete coverage: 39,386/70,852 hours (55.6%)
#     Time frame: 2021-02-09 10:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1724 days, 39,386 hours)
#     Time frame: 2021-02-09 10:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1724 days, 39,386 hours)
#     WITH outliers:    R²=0.9666 | RMSE=7.17 | n=31515
#     WITHOUT outliers: R²=0.9666 | RMSE=7.17 | n=31508
#     ΔR² = -0.0000
#
# [13/15] Marbacher Straße - Neckarbrücke
#     Training WITH outliers...
#     WITH outliers:    R²=0.9666 | RMSE=7.17 | n=31515
#     WITHOUT outliers: R²=0.9666 | RMSE=7.17 | n=31508
#     ΔR² = -0.0000
#
# [13/15] Marbacher Straße - Neckarbrücke
#     Training WITH outliers...
#     Complete coverage: 39,394/70,852 hours (55.6%)
#     Complete coverage: 39,394/70,852 hours (55.6%)
#     Time frame: 2021-02-09 10:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1724 days, 39,394 hours)
#     Time frame: 2021-02-09 10:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1724 days, 39,394 hours)
#     Training WITHOUT outliers (threshold >500)...
#     Training WITHOUT outliers (threshold >500)...
#     Complete coverage: 39,386/70,852 hours (55.6%)
#     Complete coverage: 39,386/70,852 hours (55.6%)
#     Time frame: 2021-02-09 10:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1724 days, 39,386 hours)
#     Time frame: 2021-02-09 10:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1724 days, 39,386 hours)
#     WITH outliers:    R²=0.8837 | RMSE=6.21 | n=31515
#     WITHOUT outliers: R²=0.8836 | RMSE=6.21 | n=31508
#     ΔR² = -0.0000
#
# [14/15] Königinallee
#     Training WITH outliers...
#     WITH outliers:    R²=0.8837 | RMSE=6.21 | n=31515
#     WITHOUT outliers: R²=0.8836 | RMSE=6.21 | n=31508
#     ΔR² = -0.0000
#
# [14/15] Königinallee
#     Training WITH outliers...
#     Complete coverage: 39,394/70,852 hours (55.6%)
#     Complete coverage: 39,394/70,852 hours (55.6%)
#     Time frame: 2021-02-09 10:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1724 days, 39,394 hours)
#     Time frame: 2021-02-09 10:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1724 days, 39,394 hours)
#     Training WITHOUT outliers (threshold >500)...
#     Training WITHOUT outliers (threshold >500)...
#     Complete coverage: 39,386/70,852 hours (55.6%)
#     Complete coverage: 39,386/70,852 hours (55.6%)
#     Time frame: 2021-02-09 10:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1724 days, 39,386 hours)
#     Time frame: 2021-02-09 10:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1724 days, 39,386 hours)
#     WITH outliers:    R²=0.5281 | RMSE=10.23 | n=31515
#     WITHOUT outliers: R²=0.5282 | RMSE=10.23 | n=31508
#     ΔR² = +0.0001
#
# [15/15] Friedrich-Ebert-Straße
#     Training WITH outliers...
#     WITH outliers:    R²=0.5281 | RMSE=10.23 | n=31515
#     WITHOUT outliers: R²=0.5282 | RMSE=10.23 | n=31508
#     ΔR² = +0.0001
#
# [15/15] Friedrich-Ebert-Straße
#     Training WITH outliers...
#     Complete coverage: 39,394/70,852 hours (55.6%)
#     Complete coverage: 39,394/70,852 hours (55.6%)
#     Time frame: 2021-02-09 10:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1724 days, 39,394 hours)
#     Time frame: 2021-02-09 10:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1724 days, 39,394 hours)
#     Training WITHOUT outliers (threshold >500)...
#     Training WITHOUT outliers (threshold >500)...
#     Complete coverage: 39,386/70,852 hours (55.6%)
#     Complete coverage: 39,386/70,852 hours (55.6%)
#     Time frame: 2021-02-09 10:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1724 days, 39,386 hours)
#     Time frame: 2021-02-09 10:00:00+00:00 to 2025-10-31 01:00:00+00:00 (1724 days, 39,386 hours)
#     WITH outliers:    R²=0.9591 | RMSE=18.03 | n=31515
#     WITHOUT outliers: R²=0.9591 | RMSE=18.03 | n=31508
#     ΔR² = -0.0000
#
# --------------------------------------------------------------------------------
# SUMMARY - Stadt Ludwigsburg
# --------------------------------------------------------------------------------
# Successfully trained models for 15 stations
#
# Average R² WITH outliers:    0.8762 ± 0.1169
# Average R² WITHOUT outliers: 0.8763 ± 0.1169
# Average ΔR²:                 +0.0001 ± 0.0002
#
# ================================================================================
# PROCESSING: Ravensburg Tws Gmbh & Co. Kg
# ================================================================================
#
# Stations: 7
# Records: 318,971
#
# [1/7] 03 WGT Krankenhaus Ost
#     Training WITH outliers...
#     WITH outliers:    R²=0.9591 | RMSE=18.03 | n=31515
#     WITHOUT outliers: R²=0.9591 | RMSE=18.03 | n=31508
#     ΔR² = -0.0000
#
# --------------------------------------------------------------------------------
# SUMMARY - Stadt Ludwigsburg
# --------------------------------------------------------------------------------
# Successfully trained models for 15 stations
#
# Average R² WITH outliers:    0.8762 ± 0.1169
# Average R² WITHOUT outliers: 0.8763 ± 0.1169
# Average ΔR²:                 +0.0001 ± 0.0002
#
# ================================================================================
# PROCESSING: Ravensburg Tws Gmbh & Co. Kg
# ================================================================================
#
# Stations: 7
# Records: 318,971
#
# [1/7] 03 WGT Krankenhaus Ost
#     Training WITH outliers...
#     Complete coverage: 28,962/51,883 hours (55.8%)
#     Time frame: 2020-12-17 10:00:00+00:00 to 2025-10-31 02:00:00+00:00 (1778 days, 28,962 hours)
#     Complete coverage: 28,962/51,883 hours (55.8%)
#     Time frame: 2020-12-17 10:00:00+00:00 to 2025-10-31 02:00:00+00:00 (1778 days, 28,962 hours)
#     Training WITHOUT outliers (threshold >500)...
#     Complete coverage: 28,962/51,883 hours (55.8%)
#     Training WITHOUT outliers (threshold >500)...
#     Complete coverage: 28,962/51,883 hours (55.8%)
#     Time frame: 2020-12-17 10:00:00+00:00 to 2025-10-31 02:00:00+00:00 (1778 days, 28,962 hours)
#     Time frame: 2020-12-17 10:00:00+00:00 to 2025-10-31 02:00:00+00:00 (1778 days, 28,962 hours)
#     WITH outliers:    R²=0.8018 | RMSE=7.44 | n=23169
#     WITHOUT outliers: R²=0.8018 | RMSE=7.44 | n=23169
#     ΔR² = +0.0000
#
# [2/7] 04 WGT Krankenhaus West
#     Training WITH outliers...
#     Complete coverage: 28,962/51,883 hours (55.8%)
#     WITH outliers:    R²=0.8018 | RMSE=7.44 | n=23169
#     WITHOUT outliers: R²=0.8018 | RMSE=7.44 | n=23169
#     ΔR² = +0.0000
#
# [2/7] 04 WGT Krankenhaus West
#     Training WITH outliers...
#     Complete coverage: 28,962/51,883 hours (55.8%)
#     Time frame: 2020-12-17 10:00:00+00:00 to 2025-10-31 02:00:00+00:00 (1778 days, 28,962 hours)
#     Time frame: 2020-12-17 10:00:00+00:00 to 2025-10-31 02:00:00+00:00 (1778 days, 28,962 hours)
#     Training WITHOUT outliers (threshold >500)...
#     Complete coverage: 28,962/51,883 hours (55.8%)
#     Training WITHOUT outliers (threshold >500)...
#     Complete coverage: 28,962/51,883 hours (55.8%)
#     Time frame: 2020-12-17 10:00:00+00:00 to 2025-10-31 02:00:00+00:00 (1778 days, 28,962 hours)
#     Time frame: 2020-12-17 10:00:00+00:00 to 2025-10-31 02:00:00+00:00 (1778 days, 28,962 hours)
#     WITH outliers:    R²=0.8522 | RMSE=10.61 | n=23169
#     WITHOUT outliers: R²=0.8522 | RMSE=10.61 | n=23169
#     ΔR² = +0.0000
#
# [3/7] 05 RV Eissporthalle
#     Training WITH outliers...
#     Complete coverage: 28,962/51,883 hours (55.8%)
#     WITH outliers:    R²=0.8522 | RMSE=10.61 | n=23169
#     WITHOUT outliers: R²=0.8522 | RMSE=10.61 | n=23169
#     ΔR² = +0.0000
#
# [3/7] 05 RV Eissporthalle
#     Training WITH outliers...
#     Complete coverage: 28,962/51,883 hours (55.8%)
#     Time frame: 2020-12-17 10:00:00+00:00 to 2025-10-31 02:00:00+00:00 (1778 days, 28,962 hours)
#     Time frame: 2020-12-17 10:00:00+00:00 to 2025-10-31 02:00:00+00:00 (1778 days, 28,962 hours)
#     Training WITHOUT outliers (threshold >500)...
#     Training WITHOUT outliers (threshold >500)...
#     Complete coverage: 28,962/51,883 hours (55.8%)
#     Time frame: 2020-12-17 10:00:00+00:00 to 2025-10-31 02:00:00+00:00 (1778 days, 28,962 hours)
#     Complete coverage: 28,962/51,883 hours (55.8%)
#     Time frame: 2020-12-17 10:00:00+00:00 to 2025-10-31 02:00:00+00:00 (1778 days, 28,962 hours)
#     WITH outliers:    R²=0.8499 | RMSE=5.81 | n=23169
#     WITHOUT outliers: R²=0.8499 | RMSE=5.81 | n=23169
#     ΔR² = +0.0000
#
# [4/7] 06 Meersburger Brücke abwärts
#     Training WITH outliers...
#     Complete coverage: 28,962/51,883 hours (55.8%)
#     WITH outliers:    R²=0.8499 | RMSE=5.81 | n=23169
#     WITHOUT outliers: R²=0.8499 | RMSE=5.81 | n=23169
#     ΔR² = +0.0000
#
# [4/7] 06 Meersburger Brücke abwärts
#     Training WITH outliers...
#     Complete coverage: 28,962/51,883 hours (55.8%)
#     Time frame: 2020-12-17 10:00:00+00:00 to 2025-10-31 02:00:00+00:00 (1778 days, 28,962 hours)
#     Time frame: 2020-12-17 10:00:00+00:00 to 2025-10-31 02:00:00+00:00 (1778 days, 28,962 hours)
#     Training WITHOUT outliers (threshold >500)...
#     Training WITHOUT outliers (threshold >500)...
#     Complete coverage: 28,962/51,883 hours (55.8%)
#     Time frame: 2020-12-17 10:00:00+00:00 to 2025-10-31 02:00:00+00:00 (1778 days, 28,962 hours)
#     Complete coverage: 28,962/51,883 hours (55.8%)
#     Time frame: 2020-12-17 10:00:00+00:00 to 2025-10-31 02:00:00+00:00 (1778 days, 28,962 hours)
#     WITH outliers:    R²=0.7478 | RMSE=11.45 | n=23169
#     WITHOUT outliers: R²=0.7478 | RMSE=11.45 | n=23169
#     ΔR² = +0.0000
#
# [5/7] 07 Meersburger Brücke aufwärts
#     Training WITH outliers...
#     Complete coverage: 28,962/51,883 hours (55.8%)
#     WITH outliers:    R²=0.7478 | RMSE=11.45 | n=23169
#     WITHOUT outliers: R²=0.7478 | RMSE=11.45 | n=23169
#     ΔR² = +0.0000
#
# [5/7] 07 Meersburger Brücke aufwärts
#     Training WITH outliers...
#     Complete coverage: 28,962/51,883 hours (55.8%)
#     Time frame: 2020-12-17 10:00:00+00:00 to 2025-10-31 02:00:00+00:00 (1778 days, 28,962 hours)
#     Time frame: 2020-12-17 10:00:00+00:00 to 2025-10-31 02:00:00+00:00 (1778 days, 28,962 hours)
#     Training WITHOUT outliers (threshold >500)...
#     Complete coverage: 28,962/51,883 hours (55.8%)
#     Training WITHOUT outliers (threshold >500)...
#     Complete coverage: 28,962/51,883 hours (55.8%)
#     Time frame: 2020-12-17 10:00:00+00:00 to 2025-10-31 02:00:00+00:00 (1778 days, 28,962 hours)
#     Time frame: 2020-12-17 10:00:00+00:00 to 2025-10-31 02:00:00+00:00 (1778 days, 28,962 hours)
#     WITH outliers:    R²=0.8212 | RMSE=11.68 | n=23169
#     WITHOUT outliers: R²=0.8212 | RMSE=11.68 | n=23169
#     ΔR² = +0.0000
#
# [6/7] 08 RV Bahnhofstr.
#     Training WITH outliers...
#     Complete coverage: 28,962/51,883 hours (55.8%)
#     WITH outliers:    R²=0.8212 | RMSE=11.68 | n=23169
#     WITHOUT outliers: R²=0.8212 | RMSE=11.68 | n=23169
#     ΔR² = +0.0000
#
# [6/7] 08 RV Bahnhofstr.
#     Training WITH outliers...
#     Complete coverage: 28,962/51,883 hours (55.8%)
#     Time frame: 2020-12-17 10:00:00+00:00 to 2025-10-31 02:00:00+00:00 (1778 days, 28,962 hours)
#     Time frame: 2020-12-17 10:00:00+00:00 to 2025-10-31 02:00:00+00:00 (1778 days, 28,962 hours)
#     Training WITHOUT outliers (threshold >500)...
#     Complete coverage: 28,962/51,883 hours (55.8%)
#     Training WITHOUT outliers (threshold >500)...
#     Complete coverage: 28,962/51,883 hours (55.8%)
#     Time frame: 2020-12-17 10:00:00+00:00 to 2025-10-31 02:00:00+00:00 (1778 days, 28,962 hours)
#     Time frame: 2020-12-17 10:00:00+00:00 to 2025-10-31 02:00:00+00:00 (1778 days, 28,962 hours)
#     WITH outliers:    R²=0.8746 | RMSE=10.57 | n=23169
#     WITHOUT outliers: R²=0.8746 | RMSE=10.57 | n=23169
#     ΔR² = +0.0000
#
# [7/7] 01 / 02 WGT Doggenriedstraße
#     Training WITH outliers...
#     Complete coverage: 28,962/51,883 hours (55.8%)
#     WITH outliers:    R²=0.8746 | RMSE=10.57 | n=23169
#     WITHOUT outliers: R²=0.8746 | RMSE=10.57 | n=23169
#     ΔR² = +0.0000
#
# [7/7] 01 / 02 WGT Doggenriedstraße
#     Training WITH outliers...
#     Complete coverage: 28,962/51,883 hours (55.8%)
#     Time frame: 2020-12-17 10:00:00+00:00 to 2025-10-31 02:00:00+00:00 (1778 days, 28,962 hours)
#     Time frame: 2020-12-17 10:00:00+00:00 to 2025-10-31 02:00:00+00:00 (1778 days, 28,962 hours)
#     Training WITHOUT outliers (threshold >500)...
#     Complete coverage: 28,962/51,883 hours (55.8%)
#     Training WITHOUT outliers (threshold >500)...
#     Complete coverage: 28,962/51,883 hours (55.8%)
#     Time frame: 2020-12-17 10:00:00+00:00 to 2025-10-31 02:00:00+00:00 (1778 days, 28,962 hours)
#     Time frame: 2020-12-17 10:00:00+00:00 to 2025-10-31 02:00:00+00:00 (1778 days, 28,962 hours)
#     WITH outliers:    R²=0.7970 | RMSE=4.86 | n=23169
#     WITHOUT outliers: R²=0.7970 | RMSE=4.86 | n=23169
#     ΔR² = +0.0000
#
# --------------------------------------------------------------------------------
# SUMMARY - Ravensburg Tws Gmbh & Co. Kg
# --------------------------------------------------------------------------------
# Successfully trained models for 7 stations
#
# Average R² WITH outliers:    0.8206 ± 0.0428
# Average R² WITHOUT outliers: 0.8206 ± 0.0428
# Average ΔR²:                 +0.0000 ± 0.0000
#
#
# ================================================================================
# ALL CITIES PROCESSED
# ================================================================================
#     WITH outliers:    R²=0.7970 | RMSE=4.86 | n=23169
#     WITHOUT outliers: R²=0.7970 | RMSE=4.86 | n=23169
#     ΔR² = +0.0000
#
# --------------------------------------------------------------------------------
# SUMMARY - Ravensburg Tws Gmbh & Co. Kg
# --------------------------------------------------------------------------------
# Successfully trained models for 7 stations
#
# Average R² WITH outliers:    0.8206 ± 0.0428
# Average R² WITHOUT outliers: 0.8206 ± 0.0428
# Average ΔR²:                 +0.0000 ± 0.0000
#
#
# ================================================================================
# ALL CITIES PROCESSED
# ================================================================================

# %%
################################################
# DISPLAY RESULTS PER CITY                     #
################################################

for city_name, city_results in all_city_results.items():
    if len(city_results) == 0:
        continue
    
    df_city_results = pd.DataFrame(city_results)
    
    print(f"\n{'='*120}")
    print(f"{city_name} (outlier threshold: >{OUTLIER_THRESHOLD})")
    print(f"{'='*120}")
    print(f"\n| Station | R² (with) | RMSE (with) | MAE (with) | R² (no outl) | RMSE (no outl) | MAE (no outl) | ΔR² | Features | n_train | n_train_no_outl |")
    print(f"|---------|-----------|-------------|------------|--------------|----------------|---------------|-----|----------|---------|-----------------|")
    
    for _, row in df_city_results.iterrows():
        print(f"| {row['station'][:30]:30} | "
              f"{row['test_r2_with']:9.4f} | "
              f"{row['test_rmse_with']:11.2f} | "
              f"{row['test_mae_with']:10.2f} | "
              f"{row['test_r2_without']:12.4f} | "
              f"{row['test_rmse_without']:14.2f} | "
              f"{row['test_mae_without']:13.2f} | "
              f"{row['delta_r2']:+7.4f} | "
              f"{row['n_features']:8} | "
              f"{row['n_train_samples']:7} | "
              f"{row['n_train_samples_no_outliers']:15} |")
    
    print(f"\nSummary Statistics:")
    print(f"  Outlier threshold:         >{OUTLIER_THRESHOLD} hourly counts")
    print(f"  Avg R² (with outliers):    {df_city_results['test_r2_with'].mean():.4f} ± {df_city_results['test_r2_with'].std():.4f}")
    print(f"  Avg R² (no outliers):      {df_city_results['test_r2_without'].mean():.4f} ± {df_city_results['test_r2_without'].std():.4f}")
    print(f"  Avg ΔR²:                   {df_city_results['delta_r2'].mean():+.4f} ± {df_city_results['delta_r2'].std():.4f}")
    print(f"  Avg RMSE (with outliers):  {df_city_results['test_rmse_with'].mean():.2f} ± {df_city_results['test_rmse_with'].std():.2f}")
    print(f"  Avg RMSE (no outliers):    {df_city_results['test_rmse_without'].mean():.2f} ± {df_city_results['test_rmse_without'].std():.2f}")
# Out:
# ========================================================================================================================
# Stadt Freiburg (outlier threshold: >1000)
# ========================================================================================================================
#
# | Station | R² (with) | RMSE (with) | MAE (with) | R² (no outl) | RMSE (no outl) | MAE (no outl) | ΔR² | Features | n_train | n_train_no_outl |
# |---------|-----------|-------------|------------|--------------|----------------|---------------|-----|----------|---------|-----------------|
# | Wiwilibrücke                   |    0.9733 |       53.05 |      38.02 |       0.9712 |          50.37 |         36.16 | -0.0021 |       12 |    4853 |            4576 |
# | FR2 Güterbahn / Ferd.-Weiß-Str |    0.9682 |       25.60 |      16.49 |       0.9598 |          25.36 |         16.17 | -0.0083 |       12 |    4853 |            4576 |
# | FR1 Dreisam / Otto-Wels-Str.   |    0.7984 |      109.33 |      69.04 |       0.7507 |         108.87 |         69.24 | -0.0478 |       12 |    4853 |            4576 |
# | FR3 Eschholzstr. / Egonstr. ei |    0.9531 |       21.28 |      15.63 |       0.9443 |          21.01 |         15.33 | -0.0087 |       12 |    4853 |            4576 |
# | Mundenhof 2 - Mundenhofer Str. |    0.6693 |       16.40 |      10.82 |       0.6109 |          16.27 |         10.74 | -0.0583 |       12 |    4853 |            4576 |
# | H.-v.-Stephan-Str. 9 / JobRad  |    0.9217 |       14.54 |      10.78 |       0.9084 |          13.92 |         10.28 | -0.0133 |       12 |    4853 |            4576 |
# | H.-v.-Stephan-Str. 9 / JobRad  |    0.8966 |       16.14 |      11.71 |       0.8890 |          15.45 |         10.89 | -0.0076 |       12 |    4853 |            4576 |
# | FR6 Rotteckring / H Theater -  |    0.9537 |       64.32 |      47.32 |       0.9492 |          61.77 |         45.77 | -0.0045 |       12 |    4853 |            4576 |
# | FR2 Elsässer Str. / Uniklinik  |    0.9171 |       34.71 |      19.57 |       0.8989 |          33.59 |         17.89 | -0.0182 |       12 |    4853 |            4576 |
# | FR8 Schützenallee / Stadthalle |    0.9415 |       27.76 |      19.20 |       0.9359 |          26.53 |         18.26 | -0.0056 |       12 |    4853 |            4576 |
#
# Summary Statistics:
#   Outlier threshold:         >1000 hourly counts
#   Avg R² (with outliers):    0.8993 ± 0.0953
#   Avg R² (no outliers):      0.8818 ± 0.1141
#   Avg ΔR²:                   -0.0174 ± 0.0195
#   Avg RMSE (with outliers):  38.31 ± 29.91
#   Avg RMSE (no outliers):    37.32 ± 29.62
#
# ========================================================================================================================
# Landeshauptstadt Stuttgart (outlier threshold: >1000)
# ========================================================================================================================
#
# | Station | R² (with) | RMSE (with) | MAE (with) | R² (no outl) | RMSE (no outl) | MAE (no outl) | ΔR² | Features | n_train | n_train_no_outl |
# |---------|-----------|-------------|------------|--------------|----------------|---------------|-----|----------|---------|-----------------|
# | König-Karls-Brücke Barometer   |    0.8407 |       41.07 |      25.81 |       0.8400 |          41.16 |         25.88 | -0.0007 |       17 |   36125 |           36123 |
# | Böblinger Straße               |    0.8460 |       21.10 |      12.08 |       0.8460 |          21.10 |         12.08 | -0.0000 |       17 |   36125 |           36123 |
# | Taubenheimstraße               |    0.5070 |        7.74 |       5.33 |       0.5323 |           7.54 |          5.19 | +0.0253 |       17 |   36125 |           36123 |
# | Waiblinger Straße              |    0.8532 |        4.69 |       3.26 |       0.8533 |           4.68 |          3.26 | +0.0001 |       17 |   36125 |           36123 |
# | Samaraweg                      |    0.8604 |       25.80 |      14.79 |       0.8613 |          25.72 |         14.73 | +0.0010 |       17 |   36125 |           36123 |
# | Waldburgstraße                 |    0.8347 |       10.42 |       5.24 |       0.8357 |          10.39 |          5.23 | +0.0011 |       17 |   36125 |           36123 |
# | Kremmlerstraße                 |    0.8883 |       13.06 |       8.17 |       0.8887 |          13.04 |          8.16 | +0.0005 |       17 |   36125 |           36123 |
# | Kirchheimer Straße             |    0.9119 |        7.86 |       5.12 |       0.9124 |           7.84 |          5.11 | +0.0005 |       17 |   36125 |           36123 |
# | Stuttgarter Straße             |    0.7707 |        8.89 |       5.33 |       0.7706 |           8.89 |          5.33 | -0.0001 |       17 |   36125 |           36123 |
# | Solitudestraße                 |    0.8214 |        8.30 |       5.03 |       0.8216 |           8.30 |          5.03 | +0.0001 |       17 |   36125 |           36123 |
# | Am Kräherwald                  |    0.8670 |        6.75 |       4.37 |       0.8669 |           6.75 |          4.37 | -0.0002 |       17 |   36125 |           36123 |
# | Inselstraße                    |    0.9057 |       13.20 |       7.79 |       0.9058 |          13.20 |          7.77 | +0.0001 |       17 |   36125 |           36123 |
# | Neckartalstraße                |    0.3869 |       13.25 |       8.63 |       0.3803 |          13.32 |          8.66 | -0.0066 |       17 |   36125 |           36123 |
# | Lautenschlager Straße          |    0.8215 |       20.90 |      14.12 |       0.8215 |          20.90 |         14.12 | -0.0000 |       17 |   36125 |           36123 |
# | Tübinger Straße                |    0.9190 |       29.42 |      20.97 |       0.9190 |          29.40 |         20.96 | +0.0001 |       17 |   36125 |           36123 |
#
# Summary Statistics:
#   Outlier threshold:         >1000 hourly counts
#   Avg R² (with outliers):    0.8023 ± 0.1511
#   Avg R² (no outliers):      0.8037 ± 0.1491
#   Avg ΔR²:                   +0.0014 ± 0.0068
#   Avg RMSE (with outliers):  15.50 ± 10.23
#   Avg RMSE (no outliers):    15.48 ± 10.25
#
# ========================================================================================================================
# Stadt Mannheim (outlier threshold: >1000)
# ========================================================================================================================
#
# | Station | R² (with) | RMSE (with) | MAE (with) | R² (no outl) | RMSE (no outl) | MAE (no outl) | ΔR² | Features | n_train | n_train_no_outl |
# |---------|-----------|-------------|------------|--------------|----------------|---------------|-----|----------|---------|-----------------|
# | Renzstraße                     |    0.9650 |       24.98 |      18.63 |       0.9652 |          24.93 |         18.62 | +0.0002 |       16 |   15768 |           15767 |
# | Kurpfalzbrücke                 |    0.5677 |       93.48 |      56.89 |       0.5690 |          93.35 |         56.72 | +0.0013 |       16 |   15768 |           15767 |
# | Jungbuschbrücke                |    0.8304 |       16.97 |      12.28 |       0.8272 |          17.13 |         12.38 | -0.0032 |       16 |   15768 |           15767 |
# | Konrad-Adenauer-Brücke         |    0.9565 |       18.48 |      12.07 |       0.9565 |          18.48 |         12.07 | +0.0000 |       16 |   15768 |           15767 |
# | Lindenhofüberführung           |    0.2558 |       46.90 |      27.49 |       0.2624 |          46.69 |         27.47 | +0.0066 |       16 |   15768 |           15767 |
# | Neckarauer Übergang -Schwetzin |    0.9123 |       10.97 |       7.64 |       0.9124 |          10.96 |          7.63 | +0.0001 |       16 |   15768 |           15767 |
# | Schlosspark Lindenhof (Richtun |    0.9535 |       12.53 |       7.91 |       0.9537 |          12.51 |          7.91 | +0.0002 |       16 |   15768 |           15767 |
# | Feudenheimstr. stadtauswärts   |    0.7334 |       12.09 |       7.44 |       0.7334 |          12.09 |          7.43 | -0.0000 |       16 |   15768 |           15767 |
# | Feudenheimerstr. stadteinwärts |    0.7868 |        8.23 |       5.69 |       0.7868 |           8.23 |          5.69 | +0.0000 |       16 |   15768 |           15767 |
# | Luzenbergstr.                  |    0.8495 |        9.84 |       7.16 |       0.8661 |           9.28 |          6.83 | +0.0167 |       16 |   15768 |           15767 |
# | B38. RI. AUS                   |   -0.2331 |       35.09 |      20.37 |      -0.2263 |          34.99 |         20.52 | +0.0068 |       16 |   15768 |           15767 |
# | Theodor-Heuss-Anlage. RI. IN.  |    0.8611 |        7.36 |       4.89 |       0.8619 |           7.34 |          4.87 | +0.0009 |       16 |   15768 |           15767 |
# | Theodor-Heuss-Anlage. RI. AUS  |    0.7570 |        5.87 |       3.89 |       0.7573 |           5.86 |          3.89 | +0.0003 |       16 |   15768 |           15767 |
# | Fernmeldeturm.                 |    0.9237 |       22.31 |      15.71 |       0.9239 |          22.29 |         15.71 | +0.0002 |       16 |   15768 |           15767 |
#
# Summary Statistics:
#   Outlier threshold:         >1000 hourly counts
#   Avg R² (with outliers):    0.7228 ± 0.3341
#   Avg R² (no outliers):      0.7250 ± 0.3323
#   Avg ΔR²:                   +0.0021 ± 0.0049
#   Avg RMSE (with outliers):  23.22 ± 23.28
#   Avg RMSE (no outliers):    23.15 ± 23.26
#
# ========================================================================================================================
# Stadt Reutlingen (outlier threshold: >1000)
# ========================================================================================================================
#
# | Station | R² (with) | RMSE (with) | MAE (with) | R² (no outl) | RMSE (no outl) | MAE (no outl) | ΔR² | Features | n_train | n_train_no_outl |
# |---------|-----------|-------------|------------|--------------|----------------|---------------|-----|----------|---------|-----------------|
# | Tübinger Tor                   |    0.7325 |       32.01 |      14.15 |       0.8879 |          20.63 |         11.93 | +0.1555 |       10 |   31284 |           31204 |
# | Charlottenstraße               |    0.5401 |       19.93 |       9.18 |       0.7698 |          14.04 |          7.81 | +0.2297 |       10 |   31284 |           31204 |
# | Konrad-Adenauer-Straße         |    0.8865 |        6.13 |       4.18 |       0.8874 |           6.08 |          4.15 | +0.0009 |       10 |   31284 |           31204 |
# | Metzgerstraße                  |   -0.7899 |       30.87 |       9.64 |       0.5541 |          15.36 |          6.82 | +1.3440 |       10 |   31284 |           31204 |
# | Bellinostraße                  |    0.2603 |       35.69 |      11.38 |       0.8053 |          18.26 |          7.94 | +0.5450 |       10 |   31284 |           31204 |
# | Hindenburgstraße               |   -0.0006 |      306.00 |      40.06 |       0.4906 |          34.02 |          8.18 | +0.4912 |       10 |   31284 |           31204 |
# | Moltkestraße                   |    0.6947 |        7.06 |       3.81 |       0.8022 |           5.66 |          3.47 | +0.1075 |       10 |   31284 |           31204 |
# | Unter den Linden               |    0.8670 |       11.32 |       7.49 |       0.9024 |           9.65 |          6.95 | +0.0354 |       10 |   31284 |           31204 |
#
# Summary Statistics:
#   Outlier threshold:         >1000 hourly counts
#   Avg R² (with outliers):    0.3988 ± 0.5692
#   Avg R² (no outliers):      0.7625 ± 0.1566
#   Avg ΔR²:                   +0.3636 ± 0.4434
#   Avg RMSE (with outliers):  56.13 ± 101.63
#   Avg RMSE (no outliers):    15.46 ± 9.25
#
# ========================================================================================================================
# Stadt Konstanz (outlier threshold: >1000)
# ========================================================================================================================
#
# | Station | R² (with) | RMSE (with) | MAE (with) | R² (no outl) | RMSE (no outl) | MAE (no outl) | ΔR² | Features | n_train | n_train_no_outl |
# |---------|-----------|-------------|------------|--------------|----------------|---------------|-----|----------|---------|-----------------|
# | Herosepark                     |    0.9636 |       61.52 |      41.46 |       0.9658 |          55.11 |         37.71 | +0.0022 |        8 |    6540 |            6223 |
# | Bahnhaltepunkt Fürstenberg     |    0.9434 |       31.74 |      19.84 |       0.9407 |          30.39 |         19.05 | -0.0026 |        8 |    6540 |            6223 |
# | Bahnhaltepunkt Petershausen    |    0.9717 |       23.61 |      15.30 |       0.9707 |          22.42 |         14.58 | -0.0010 |        8 |    6540 |            6223 |
# | Alte Rheinbrücke               |    0.9289 |       62.24 |      41.08 |       0.9440 |          52.83 |         34.98 | +0.0151 |        8 |    6540 |            6223 |
# | Friedrichstraße                |    0.8442 |       33.19 |      23.99 |       0.8455 |          30.66 |         22.23 | +0.0013 |        8 |    6540 |            6223 |
# | Beethovenstraße                |    0.9135 |       12.81 |       8.89 |       0.9198 |          11.65 |          7.95 | +0.0063 |        8 |    6540 |            6223 |
#
# Summary Statistics:
#   Outlier threshold:         >1000 hourly counts
#   Avg R² (with outliers):    0.9275 ± 0.0462
#   Avg R² (no outliers):      0.9311 ± 0.0458
#   Avg ΔR²:                   +0.0035 ± 0.0064
#   Avg RMSE (with outliers):  37.52 ± 20.22
#   Avg RMSE (no outliers):    33.84 ± 17.07
#
# ========================================================================================================================
# Stadt Tübingen (outlier threshold: >1000)
# ========================================================================================================================
#
# | Station | R² (with) | RMSE (with) | MAE (with) | R² (no outl) | RMSE (no outl) | MAE (no outl) | ΔR² | Features | n_train | n_train_no_outl |
# |---------|-----------|-------------|------------|--------------|----------------|---------------|-----|----------|---------|-----------------|
# | Fuß- & Radtunnel Südportal - D |    0.9137 |       56.91 |      40.21 |       0.9147 |          56.60 |         39.80 | +0.0010 |        7 |    9941 |            9929 |
# | Unterführung Steinlach/Karlstr |    0.6965 |      133.94 |      79.33 |       0.6964 |         133.99 |         79.69 | -0.0001 |        7 |    9941 |            9929 |
# | Neckartalradweg Hirschau - par |    0.2425 |       36.92 |      26.73 |       0.2239 |          37.38 |         26.46 | -0.0186 |        7 |    9941 |            9929 |
# | Radbrücke Mitte - Wöhrdstraße  |    0.5465 |       61.16 |      43.34 |       0.5254 |          62.57 |         43.10 | -0.0210 |        7 |    9941 |            9929 |
# | Radbrücke Ost                  |    0.7902 |       20.58 |      13.35 |       0.7867 |          20.75 |         13.06 | -0.0034 |        7 |    9941 |            9929 |
#
# Summary Statistics:
#   Outlier threshold:         >1000 hourly counts
#   Avg R² (with outliers):    0.6379 ± 0.2585
#   Avg R² (no outliers):      0.6294 ± 0.2673
#   Avg ΔR²:                   -0.0084 ± 0.0106
#   Avg RMSE (with outliers):  61.90 ± 43.43
#   Avg RMSE (no outliers):    62.26 ± 43.36
#
# ========================================================================================================================
# Stadt Ludwigsburg (outlier threshold: >1000)
# ========================================================================================================================
#
# | Station | R² (with) | RMSE (with) | MAE (with) | R² (no outl) | RMSE (no outl) | MAE (no outl) | ΔR² | Features | n_train | n_train_no_outl |
# |---------|-----------|-------------|------------|--------------|----------------|---------------|-----|----------|---------|-----------------|
# | Alleenstraße                   |    0.9382 |       31.82 |      19.80 |       0.9383 |          31.79 |         19.76 | +0.0001 |       17 |   31515 |           31508 |
# | Marbacher Straße - Favoritepar |    0.9813 |        7.70 |       4.97 |       0.9814 |           7.70 |          4.96 | +0.0000 |       17 |   31515 |           31508 |
# | Schlieffenstraße               |    0.8992 |        6.34 |       4.20 |       0.8992 |           6.34 |          4.20 | +0.0001 |       17 |   31515 |           31508 |
# | Fuchshof                       |    0.9492 |        8.36 |       5.55 |       0.9492 |           8.36 |          5.55 | -0.0000 |       17 |   31515 |           31508 |
# | Seestraße                      |    0.9015 |        7.43 |       4.86 |       0.9023 |           7.40 |          4.84 | +0.0008 |       17 |   31515 |           31508 |
# | Schlossstraße                  |    0.9724 |        9.34 |       5.99 |       0.9724 |           9.33 |          5.99 | +0.0000 |       17 |   31515 |           31508 |
# | Kesseläcker (Verl. Nussackerwe |    0.7996 |        4.33 |       2.93 |       0.7995 |           4.34 |          2.93 | -0.0001 |       17 |   31515 |           31508 |
# | Zugwiesen                      |    0.7606 |       27.27 |      17.82 |       0.7606 |          27.28 |         17.82 | -0.0000 |       17 |   31515 |           31508 |
# | Bismarckstraße                 |    0.8134 |       11.14 |       7.64 |       0.8138 |          11.13 |          7.63 | +0.0004 |       17 |   31515 |           31508 |
# | Solitudeallee                  |    0.9132 |        7.01 |       4.50 |       0.9133 |           7.01 |          4.49 | +0.0000 |       17 |   31515 |           31508 |
# | Aldinger Straße                |    0.8762 |        5.31 |       3.44 |       0.8761 |           5.31 |          3.44 | -0.0000 |       17 |   31515 |           31508 |
# | Bottwartalstraße               |    0.9666 |        7.17 |       4.29 |       0.9666 |           7.17 |          4.29 | -0.0000 |       17 |   31515 |           31508 |
# | Marbacher Straße - Neckarbrück |    0.8837 |        6.21 |       4.22 |       0.8836 |           6.21 |          4.22 | -0.0000 |       17 |   31515 |           31508 |
# | Königinallee                   |    0.5281 |       10.23 |       6.93 |       0.5282 |          10.23 |          6.93 | +0.0001 |       17 |   31515 |           31508 |
# | Friedrich-Ebert-Straße         |    0.9591 |       18.03 |      10.37 |       0.9591 |          18.03 |         10.37 | -0.0000 |       17 |   31515 |           31508 |
#
# Summary Statistics:
#   Outlier threshold:         >1000 hourly counts
#   Avg R² (with outliers):    0.8762 ± 0.1169
#   Avg R² (no outliers):      0.8763 ± 0.1169
#   Avg ΔR²:                   +0.0001 ± 0.0002
#   Avg RMSE (with outliers):  11.18 ± 8.16
#   Avg RMSE (no outliers):    11.17 ± 8.16
#
# ========================================================================================================================
# Ravensburg Tws Gmbh & Co. Kg (outlier threshold: >1000)
# ========================================================================================================================
#
# | Station | R² (with) | RMSE (with) | MAE (with) | R² (no outl) | RMSE (no outl) | MAE (no outl) | ΔR² | Features | n_train | n_train_no_outl |
# |---------|-----------|-------------|------------|--------------|----------------|---------------|-----|----------|---------|-----------------|
# | 03 WGT Krankenhaus Ost         |    0.8018 |        7.44 |       5.11 |       0.8018 |           7.44 |          5.11 | +0.0000 |        9 |   23169 |           23169 |
# | 04 WGT Krankenhaus West        |    0.8522 |       10.61 |       7.38 |       0.8522 |          10.61 |          7.38 | +0.0000 |        9 |   23169 |           23169 |
# | 05 RV Eissporthalle            |    0.8499 |        5.81 |       4.06 |       0.8499 |           5.81 |          4.06 | +0.0000 |        9 |   23169 |           23169 |
# | 06 Meersburger Brücke abwärts  |    0.7478 |       11.45 |       7.08 |       0.7478 |          11.45 |          7.08 | +0.0000 |        9 |   23169 |           23169 |
# | 07 Meersburger Brücke aufwärts |    0.8212 |       11.68 |       7.30 |       0.8212 |          11.68 |          7.30 | +0.0000 |        9 |   23169 |           23169 |
# | 08 RV Bahnhofstr.              |    0.8746 |       10.57 |       7.18 |       0.8746 |          10.57 |          7.18 | +0.0000 |        9 |   23169 |           23169 |
# | 01 / 02 WGT Doggenriedstraße   |    0.7970 |        4.86 |       3.30 |       0.7970 |           4.86 |          3.30 | +0.0000 |        9 |   23169 |           23169 |
#
# Summary Statistics:
#   Outlier threshold:         >1000 hourly counts
#   Avg R² (with outliers):    0.8206 ± 0.0428
#   Avg R² (no outliers):      0.8206 ± 0.0428
#   Avg ΔR²:                   +0.0000 ± 0.0000
#   Avg RMSE (with outliers):  8.92 ± 2.83
#   Avg RMSE (no outliers):    8.92 ± 2.83
